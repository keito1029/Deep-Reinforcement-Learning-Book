# %% [markdown]
# ## 2.3 方策反復法の実装

# %%
# 使用するパッケージの宣言
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 初期位置での迷路の様子

# 図を描く大きさと、図の変数名を宣言
fig = plt.figure(figsize=(5, 5))
ax = plt.gca()

# 赤い壁を描く
plt.plot([1, 1], [0, 1], color='red', linewidth=2)
plt.plot([1, 2], [2, 2], color='red', linewidth=2)
plt.plot([2, 2], [2, 1], color='red', linewidth=2)
plt.plot([2, 3], [1, 1], color='red', linewidth=2)
plt.plot([3, 3], [3, 4], color='red', linewidth=2)
plt.plot([1, 2], [3, 3], color='red', linewidth=2)
plt.plot([3, 3], [1, 2], color='red', linewidth=2)

# 状態を示す文字S0～S12を描く
plt.text(0.5, 3.5, 'S0', size=14, ha='center')
plt.text(1.5, 3.5, 'S1', size=14, ha='center')
plt.text(2.5, 3.5, 'S2', size=14, ha='center')
plt.text(3.5, 3.5, 'S3', size=14, ha='center')
plt.text(0.5, 2.5, 'S4', size=14, ha='center')
plt.text(1.5, 2.5, 'S5', size=14, ha='center')
plt.text(2.5, 2.5, 'S6', size=14, ha='center')
plt.text(3.5, 2.5, 'S7', size=14, ha='center')
plt.text(0.5, 1.5, 'S8', size=14, ha='center')
plt.text(1.5, 1.5, 'S9', size=14, ha='center')
plt.text(2.5, 1.5, 'S10', size=14, ha='center')
plt.text(3.5, 1.5, 'S11', size=14, ha='center')
plt.text(0.5, 0.5, 'S12', size=14, ha='center')
plt.text(1.5, 0.5, 'S13', size=14, ha='center')
plt.text(2.5, 0.5, 'S14', size=14, ha='center')
plt.text(3.5, 0.5, 'S15', size=14, ha='center')
plt.text(0.5, 3.3, 'START', ha='center')
plt.text(3.5, 0.3, 'GOAL', ha='center')

# 描画範囲の設定と目盛りを消す設定
ax.set_xlim(0, 4)
ax.set_ylim(0, 4)
plt.tick_params(axis='both', which='both', bottom='off', top='off',
                labelbottom='off', right='off', left='off', labelleft='off')

# 現在地S0に緑丸を描画する
line, = ax.plot([0.5], [3.5], marker="o", color='b', markersize=60)

# %%
# 初期の方策を決定するパラメータtheta_0を設定

# 行は状態0～7、列は移動方向で↑、→、↓、←、右上、左上、右下、左下を表す
theta_0 = np.array([[np.nan, 1, 1, np.nan, np.nan, np.nan, 1, np.nan],  # s0
                    [np.nan, 1, np.nan, 1, np.nan, np.nan, 1, 1],  # s1
                    [np.nan, np.nan, 1, 1, np.nan ,np.nan, 1, 1],  # s2
                    [np.nan, np.nan, 1, np.nan, np.nan, np.nan, np.nan, 1],  # s3
                    [1, 1, 1, np.nan, 1, np.nan, 1, np.nan],  # s4
                    [np.nan, 1, np.nan, 1, 1, 1, 1, 1],  # s5
                    [1, 1, 1, 1, 1, 1, np.nan, np.nan],  # s6
                    [1, np.nan, 1, 1, np.nan, 1, np.nan, 1],# s7
                    [1, 1, 1, np.nan, 1, np.nan, 1, np.nan],  # s8
                    [np.nan, np.nan, 1, 1, np.nan, 1, 1, 1],  # s9
                    [1, np.nan, np.nan, np.nan, 1, 1, np.nan, np.nan],  # s10
                    [1, np.nan, 1, np.nan, np.nan, 1, np.nan, 1],  # s11
                    [1, np.nan, np.nan, np.nan, 1, np.nan, np.nan, np.nan],  # s12
                    [1, 1, np.nan, np.nan, np.nan, 1, np.nan, np.nan],  # s13
                    [np.nan, 1, np.nan, 1, 1, 1, np.nan, np.nan],  # s14
                    # ※s15はゴールなので、方策はなし
                    ])

# %%
# 方策パラメータthetaを行動方策piにソフトマックス関数で変換する手法の定義


def softmax_convert_into_pi_from_theta(theta):
    '''ソフトマックス関数で割合を計算する'''

    beta = 1.0
    [m, n] = theta.shape  # thetaの行列サイズを取得
    pi = np.zeros((m, n))

    exp_theta = np.exp(beta * theta)  # thetaをexp(theta)へと変換

    for i in range(0, m):
        # pi[i, :] = theta[i, :] / np.nansum(theta[i, :])
        # simpleに割合の計算の場合

        pi[i, :] = exp_theta[i, :] / np.nansum(exp_theta[i, :])
        # softmaxで計算の場合

    pi = np.nan_to_num(pi)  # nanを0に変換

    return pi

# %%
# 初期の方策pi_0を求める
pi_0 = softmax_convert_into_pi_from_theta(theta_0)
print(pi_0)
# Out:
# [[0.         0.33333333 0.33333333 0.         0.         0.
#   0.33333333 0.        ]
#  [0.         0.25       0.         0.25       0.         0.
#   0.25       0.25      ]
#  [0.         0.         0.25       0.25       0.         0.
#   0.25       0.25      ]
#  [0.         0.         0.5        0.         0.         0.
#   0.         0.5       ]
#  [0.2        0.2        0.2        0.         0.2        0.
#   0.2        0.        ]
#  [0.         0.16666667 0.         0.16666667 0.16666667 0.16666667
#   0.16666667 0.16666667]
#  [0.16666667 0.16666667 0.16666667 0.16666667 0.16666667 0.16666667
#   0.         0.        ]
#  [0.2        0.         0.2        0.2        0.         0.2
#   0.         0.2       ]
#  [0.2        0.2        0.2        0.         0.2        0.
#   0.2        0.        ]
#  [0.         0.         0.2        0.2        0.         0.2
#   0.2        0.2       ]
#  [0.33333333 0.         0.         0.         0.33333333 0.33333333
#   0.         0.        ]
#  [0.25       0.         0.25       0.         0.         0.25
#   0.         0.25      ]
#  [0.5        0.         0.         0.         0.5        0.
#   0.         0.        ]
#  [0.33333333 0.33333333 0.         0.         0.         0.33333333
#   0.         0.        ]
#  [0.         0.25       0.         0.25       0.25       0.25
#   0.         0.        ]]

# %%
# 初期の方策pi_0を表示
pi_0
# Out:
# array([[0.        , 0.33333333, 0.33333333, 0.        , 0.        ,
#         0.        , 0.33333333, 0.        ],
#        [0.        , 0.25      , 0.        , 0.25      , 0.        ,
#         0.        , 0.25      , 0.25      ],
#        [0.        , 0.        , 0.25      , 0.25      , 0.        ,
#         0.        , 0.25      , 0.25      ],
#        [0.        , 0.        , 0.5       , 0.        , 0.        ,
#         0.        , 0.        , 0.5       ],
#        [0.2       , 0.2       , 0.2       , 0.        , 0.2       ,
#         0.        , 0.2       , 0.        ],
#        [0.        , 0.16666667, 0.        , 0.16666667, 0.16666667,
#         0.16666667, 0.16666667, 0.16666667],
#        [0.16666667, 0.16666667, 0.16666667, 0.16666667, 0.16666667,
#         0.16666667, 0.        , 0.        ],
#        [0.2       , 0.        , 0.2       , 0.2       , 0.        ,
#         0.2       , 0.        , 0.2       ],
#        [0.2       , 0.2       , 0.2       , 0.        , 0.2       ,
#         0.        , 0.2       , 0.        ],
#        [0.        , 0.        , 0.2       , 0.2       , 0.        ,
#         0.2       , 0.2       , 0.2       ],
#        [0.33333333, 0.        , 0.        , 0.        , 0.33333333,
#         0.33333333, 0.        , 0.        ],
#        [0.25      , 0.        , 0.25      , 0.        , 0.        ,
#         0.25      , 0.        , 0.25      ],
#        [0.5       , 0.        , 0.        , 0.        , 0.5       ,
#         0.        , 0.        , 0.        ],
#        [0.33333333, 0.33333333, 0.        , 0.        , 0.        ,
#         0.33333333, 0.        , 0.        ],
#        [0.        , 0.25      , 0.        , 0.25      , 0.25      ,
#         0.25      , 0.        , 0.        ]])

# %%
# 1step移動後の状態sを求める関数を定義


def get_action_and_next_s(pi, s):
    direction = ["up", "right", "down", "left","upper right","upper left","lower right","lower left"]

    next_direction = np.random.choice(direction, p=pi[s, :])
    # pi[s,:]の確率に従って、directionが選択される

    if next_direction == "up":
        action = 0
        s_next = s - 4  # 上に移動するときは状態の数字が3小さくなる
    elif next_direction == "right":
        action = 1
        s_next = s + 1  # 右に移動するときは状態の数字が1大きくなる
    elif next_direction == "down":
        action = 2
        s_next = s + 4  # 下に移動するときは状態の数字が3大きくなる
    elif next_direction == "left":
        action = 3
        s_next = s - 1  # 左に移動するときは状態の数字が1小さくなる
    elif next_direction == "upper right":
        action = 4
        s_next = s - 3  # 右上に移動するときは状態の数字が2小さくなる
    elif next_direction == "upper left":
        action = 5
        s_next = s - 5  # 左上に移動するときは状態の数字が4小さくなる
    elif next_direction == "lower right":
        action = 6
        s_next = s + 5  # 右下に移動するときは状態の数字が4大きくなる
    elif next_direction == "lower left":
        action = 7
        s_next = s + 3  # 左下に移動するときは状態の数字が2大きくなる
    return [action, s_next]

# %%
# 迷路を解く関数の定義、状態と行動の履歴を出力


def goal_maze_ret_s_a(pi):
    s = 0  # スタート地点
    s_a_history = [[0, np.nan]]  # エージェントの移動を記録するリスト

    while (1):  # ゴールするまでループ
        [action, next_s] = get_action_and_next_s(pi, s)
        s_a_history[-1][1] = action
        # 現在の状態（つまり一番最後なのでindex=-1）の行動を代入

        s_a_history.append([next_s, np.nan])
        # 次の状態を代入。行動はまだ分からないのでnanにしておく

        if next_s == 15:  # ゴール地点なら終了
            break
        else:
            s = next_s

    return s_a_history

# %%
# 初期の方策で迷路を解く
s_a_history = goal_maze_ret_s_a(pi_0)
print(s_a_history)
print("迷路を解くのにかかったステップ数は" + str(len(s_a_history) - 1) + "です")
# Out:
# [[0, 6], [5, 7], [8, 4], [5, 7], [8, 0], [4, 6], [9, 2], [13, 5], [8, 1], [9, 5], [4, 2], [8, 6], [13, 1], [14, 1], [15, nan]]
# 迷路を解くのにかかったステップ数は14です

# %%
# thetaの更新関数を定義します


def update_theta(theta, pi, s_a_history):
    eta = 0.1 # 学習率
    T = len(s_a_history) - 1  # ゴールまでの総ステップ数

    [m, n] = theta.shape  # thetaの行列サイズを取得
    delta_theta = theta.copy()  # Δthetaの元を作成、ポインタ参照なので、delta_theta = thetaはダメ

    # delta_thetaを要素ごとに求めます
    for i in range(0, m):
        for j in range(0, n):
            if not(np.isnan(theta[i, j])):  # thetaがnanでない場合

                SA_i = [SA for SA in s_a_history if SA[0] == i]
                # 履歴から状態iのものを取り出すリスト内包表記です

                SA_ij = [SA for SA in s_a_history if SA == [i, j]]
                # 状態iで行動jをしたものを取り出す

                N_i = len(SA_i)  # 状態iで行動した総回数
                N_ij = len(SA_ij)  # 状態iで行動jをとった回数
                
                # 初版では符号の正負に間違いがありました（修正日：180703）
                #delta_theta[i, j] = (N_ij + pi[i, j] * N_i) / T
                delta_theta[i, j] = (N_ij - pi[i, j] * N_i) / T

    new_theta = theta + eta * delta_theta

    return new_theta

# %%
# 方策の更新
new_theta = update_theta(theta_0, pi_0, s_a_history)
pi = softmax_convert_into_pi_from_theta(new_theta)
print(pi)
# Out:
# [[0.         0.33253874 0.33253874 0.         0.         0.
#   0.33492252 0.        ]
#  [0.         0.25       0.         0.25       0.         0.
#   0.25       0.25      ]
#  [0.         0.         0.25       0.25       0.         0.
#   0.25       0.25      ]
#  [0.         0.         0.5        0.         0.         0.
#   0.         0.5       ]
#  [0.19942817 0.19942817 0.20085775 0.         0.19942817 0.
#   0.20085775 0.        ]
#  [0.         0.16626795 0.         0.16626795 0.16626795 0.16626795
#   0.16626795 0.16866025]
#  [0.16666667 0.16666667 0.16666667 0.16666667 0.16666667 0.16666667
#   0.         0.        ]
#  [0.2        0.         0.2        0.2        0.         0.2
#   0.         0.2       ]
#  [0.2002851  0.2002851  0.19885959 0.         0.2002851  0.
#   0.2002851  0.        ]
#  [0.         0.         0.20085775 0.19942817 0.         0.20085775
#   0.19942817 0.19942817]
#  [0.33333333 0.         0.         0.         0.33333333 0.33333333
#   0.         0.        ]
#  [0.25       0.         0.25       0.         0.         0.25
#   0.         0.25      ]
#  [0.5        0.         0.         0.         0.5        0.
#   0.         0.        ]
#  [0.33174793 0.33412604 0.         0.         0.         0.33412604
#   0.         0.        ]
#  [0.         0.25134168 0.         0.24955277 0.24955277 0.24955277
#   0.         0.        ]]

# %%
# 方策勾配法で迷路を解く

# 初版で、def update_thetaに間違いがあった関係で、終了条件を変更します（修正日：180703）
#stop_epsilon = 10**-8  # 10^-8よりも方策に変化が少なくなったら学習終了とする
stop_epsilon = 10**-4  # 10^-4よりも方策に変化が少なくなったら学習終了とする


theta = theta_0
pi = pi_0

is_continue = True
count = 1
while is_continue:  # is_continueがFalseになるまで繰り返す
    s_a_history = goal_maze_ret_s_a(pi)  # 方策πで迷路内を探索した履歴を求める
    new_theta = update_theta(theta, pi, s_a_history)  # パラメータΘを更新
    new_pi = softmax_convert_into_pi_from_theta(new_theta)  # 方策πの更新

    print(np.sum(np.abs(new_pi - pi)))  # 方策の変化を出力
    print("迷路を解くのにかかったステップ数は" + str(len(s_a_history) - 1) + "です")

    if np.sum(np.abs(new_pi - pi)) < stop_epsilon:
        is_continue = False
    else:
        theta = new_theta
        pi = new_pi
# Out:
# 0.012274026353765927
# 迷路を解くのにかかったステップ数は86です
# 0.01576771438167074
# 迷路を解くのにかかったステップ数は72です
# 0.015288420189248059
# 迷路を解くのにかかったステップ数は74です
# 0.01783658331574678
# 迷路を解くのにかかったステップ数は41です
# 0.031020843364533673
# 迷路を解くのにかかったステップ数は12です
# 0.011049278762464143
# 迷路を解くのにかかったステップ数は111です
# 0.01566053618062757
# 迷路を解くのにかかったステップ数は34です
# 0.011289601310690206
# 迷路を解くのにかかったステップ数は80です
# 0.01615573767781303
# 迷路を解くのにかかったステップ数は57です
# 0.02810140528236224
# 迷路を解くのにかかったステップ数は28です
# 0.017822359308104496
# 迷路を解くのにかかったステップ数は41です
# 0.01987217650870929
# 迷路を解くのにかかったステップ数は37です
# 0.02295027138959338
# 迷路を解くのにかかったステップ数は41です
# 0.012236917385000767
# 迷路を解くのにかかったステップ数は72です
# 0.024958591155401527
# 迷路を解くのにかかったステップ数は22です
# 0.010811005318585143
# 迷路を解くのにかかったステップ数は127です
# 0.019500461184519147
# 迷路を解くのにかかったステップ数は38です
# 0.03626954439018509
# 迷路を解くのにかかったステップ数は11です
# 0.012352804452258698
# 迷路を解くのにかかったステップ数は136です
# 0.010901369753594264
# 迷路を解くのにかかったステップ数は128です
# 0.016099957754422023
# 迷路を解くのにかかったステップ数は62です
# 0.019780236074663837
# 迷路を解くのにかかったステップ数は39です
# 0.01420786026511714
# 迷路を解くのにかかったステップ数は78です
# 0.03263012037665891
# 迷路を解くのにかかったステップ数は11です
# 0.02303845740105953
# 迷路を解くのにかかったステップ数は16です
# 0.014326641774236176
# 迷路を解くのにかかったステップ数は66です
# 0.011624671637836342
# 迷路を解くのにかかったステップ数は131です
# 0.017290054454493692
# 迷路を解くのにかかったステップ数は24です
# 0.03746589505841538
# 迷路を解くのにかかったステップ数は5です
# 0.032658507310392854
# 迷路を解くのにかかったステップ数は8です
# 0.014646080134340628
# 迷路を解くのにかかったステップ数は82です
# 0.017117645470270365
# 迷路を解くのにかかったステップ数は51です
# 0.01589936991071017
# 迷路を解くのにかかったステップ数は26です
# 0.020351826249452754
# 迷路を解くのにかかったステップ数は61です
# 0.009764318324792076
# 迷路を解くのにかかったステップ数は176です
# 0.03061019190658487
# 迷路を解くのにかかったステップ数は21です
# 0.017654619793832482
# 迷路を解くのにかかったステップ数は52です
# 0.03410489359552735
# 迷路を解くのにかかったステップ数は5です
# 0.026340874908798634
# 迷路を解くのにかかったステップ数は15です
# 0.02274840152189933
# 迷路を解くのにかかったステップ数は20です
# 0.007720923136545682
# 迷路を解くのにかかったステップ数は214です
# 0.014241343923888622
# 迷路を解くのにかかったステップ数は80です
# 0.013974228553660817
# 迷路を解くのにかかったステップ数は70です
# 0.020875070212261176
# 迷路を解くのにかかったステップ数は20です
# 0.022062199546605932
# 迷路を解くのにかかったステップ数は33です
# 0.02444827356129728
# 迷路を解くのにかかったステップ数は26です
# 0.01368997576200981
# 迷路を解くのにかかったステップ数は67です
# 0.008921652682581799
# 迷路を解くのにかかったステップ数は225です
# 0.010720466787318556
# 迷路を解くのにかかったステップ数は157です
# 0.010051132101522503
# 迷路を解くのにかかったステップ数は108です
# 0.014526024766747248
# 迷路を解くのにかかったステップ数は70です
# 0.02303780899744992
# 迷路を解くのにかかったステップ数は20です
# 0.02276178799375836
# 迷路を解くのにかかったステップ数は29です
# 0.015368182207545128
# 迷路を解くのにかかったステップ数は45です
# 0.013646711432074549
# 迷路を解くのにかかったステップ数は34です
# 0.017244940879452525
# 迷路を解くのにかかったステップ数は47です
# 0.013733274755168945
# 迷路を解くのにかかったステップ数は84です
# 0.012740210712778588
# 迷路を解くのにかかったステップ数は64です
# 0.013904970727154797
# 迷路を解くのにかかったステップ数は92です
# 0.008806038321909487
# 迷路を解くのにかかったステップ数は122です
# 0.024175499564567188
# 迷路を解くのにかかったステップ数は29です
# 0.019153827490763775
# 迷路を解くのにかかったステップ数は37です
# 0.03300196552329507
# 迷路を解くのにかかったステップ数は8です
# 0.027225864116259296
# 迷路を解くのにかかったステップ数は10です
# 0.0098117843803682
# 迷路を解くのにかかったステップ数は134です
# 0.017729402093442176
# 迷路を解くのにかかったステップ数は35です
# 0.012132905805189553
# 迷路を解くのにかかったステップ数は118です
# 0.007885955539924688
# 迷路を解くのにかかったステップ数は329です
# 0.010439893760407382
# 迷路を解くのにかかったステップ数は114です
# 0.013439805230940155
# 迷路を解くのにかかったステップ数は77です
# 0.020901299942410162
# 迷路を解くのにかかったステップ数は28です
# 0.030552985507164232
# 迷路を解くのにかかったステップ数は8です
# 0.016961150494529953
# 迷路を解くのにかかったステップ数は71です
# 0.0288303908223147
# 迷路を解くのにかかったステップ数は15です
# 0.03336605118300856
# 迷路を解くのにかかったステップ数は9です
# 0.01360699630525361
# 迷路を解くのにかかったステップ数は79です
# 0.02948573280395894
# 迷路を解くのにかかったステップ数は9です
# 0.01944539324855024
# 迷路を解くのにかかったステップ数は44です
# 0.015622217152505863
# 迷路を解くのにかかったステップ数は40です
# 0.032068134400399684
# 迷路を解くのにかかったステップ数は15です
# 0.013181485560728234
# 迷路を解くのにかかったステップ数は78です
# 0.00626105617862352
# 迷路を解くのにかかったステップ数は237です
# 0.01932952212498018
# 迷路を解くのにかかったステップ数は35です
# 0.0157730857193652
# 迷路を解くのにかかったステップ数は59です
# 0.01436121819885866
# 迷路を解くのにかかったステップ数は68です
# 0.011816921282153475
# 迷路を解くのにかかったステップ数は93です
# 0.012717646698318347
# 迷路を解くのにかかったステップ数は59です
# 0.02087333886340159
# 迷路を解くのにかかったステップ数は32です
# 0.01437937615794857
# 迷路を解くのにかかったステップ数は76です
# 0.021458865912278968
# 迷路を解くのにかかったステップ数は25です
# 0.013753340667768676
# 迷路を解くのにかかったステップ数は57です
# 0.019260830185644756
# 迷路を解くのにかかったステップ数は57です
# 0.021610546301668337
# 迷路を解くのにかかったステップ数は29です
# 0.015193552165816387
# 迷路を解くのにかかったステップ数は59です
# 0.013511138343510393
# 迷路を解くのにかかったステップ数は61です
# 0.017327057377550942
# 迷路を解くのにかかったステップ数は58です
# 0.018463162795432392
# 迷路を解くのにかかったステップ数は34です
# 0.021957464463267545
# 迷路を解くのにかかったステップ数は33です
# 0.012973618528175357
# 迷路を解くのにかかったステップ数は103です
# 0.010563382914737407
# 迷路を解くのにかかったステップ数は111です
# 0.01838912646327287
# 迷路を解くのにかかったステップ数は44です
# 0.026290221976053935
# 迷路を解くのにかかったステップ数は18です
# 0.009997963882937999
# 迷路を解くのにかかったステップ数は143です
# 0.015451616143412228
# 迷路を解くのにかかったステップ数は64です
# 0.015243062343187341
# 迷路を解くのにかかったステップ数は47です
# 0.026209000780424707
# 迷路を解くのにかかったステップ数は20です
# 0.016969857573349123
# 迷路を解くのにかかったステップ数は40です
# 0.0159124252085672
# 迷路を解くのにかかったステップ数は33です
# 0.017996037348155386
# 迷路を解くのにかかったステップ数は28です
# 0.02323066463937934
# 迷路を解くのにかかったステップ数は37です
# 0.032420309310241174
# 迷路を解くのにかかったステップ数は14です
# 0.03181951416745504
# 迷路を解くのにかかったステップ数は14です
# 0.017367405224910676
# 迷路を解くのにかかったステップ数は42です
# 0.011355220762133938
# 迷路を解くのにかかったステップ数は95です
# 0.03624316927078994
# 迷路を解くのにかかったステップ数は7です
# 0.03326883701040925
# 迷路を解くのにかかったステップ数は11です
# 0.01835279203309584
# 迷路を解くのにかかったステップ数は50です
# 0.014504489519222952
# 迷路を解くのにかかったステップ数は73です
# 0.02660103253524218
# 迷路を解くのにかかったステップ数は29です
# 0.014192146302384245
# 迷路を解くのにかかったステップ数は57です
# 0.01412487722839631
# 迷路を解くのにかかったステップ数は77です
# 0.032338168447945764
# 迷路を解くのにかかったステップ数は9です
# 0.015220261861613543
# 迷路を解くのにかかったステップ数は77です
# 0.013706393080939405
# 迷路を解くのにかかったステップ数は57です
# 0.03530630318166206
# 迷路を解くのにかかったステップ数は8です
# 0.017829057912098517
# 迷路を解くのにかかったステップ数は59です
# 0.011121443265415698
# 迷路を解くのにかかったステップ数は108です
# 0.022991871530642666
# 迷路を解くのにかかったステップ数は13です
# 0.011618076217796564
# 迷路を解くのにかかったステップ数は106です
# 0.021901346176039088
# 迷路を解くのにかかったステップ数は35です
# 0.01744845745124679
# 迷路を解くのにかかったステップ数は17です
# 0.031181816441514604
# 迷路を解くのにかかったステップ数は11です
# 0.015577078676555861
# 迷路を解くのにかかったステップ数は42です
# 0.011389590179772119
# 迷路を解くのにかかったステップ数は136です
# 0.014216413300872671
# 迷路を解くのにかかったステップ数は71です
# 0.016060364053074427
# 迷路を解くのにかかったステップ数は58です
# 0.036914169648178397
# 迷路を解くのにかかったステップ数は7です
# 0.015530399249157861
# 迷路を解くのにかかったステップ数は59です
# 0.03754417144411207
# 迷路を解くのにかかったステップ数は5です
# 0.022983975321111072
# 迷路を解くのにかかったステップ数は27です
# 0.029397692360760758
# 迷路を解くのにかかったステップ数は21です
# 0.016974361114444086
# 迷路を解くのにかかったステップ数は53です
# 0.014622974527425892
# 迷路を解くのにかかったステップ数は39です
# 0.028838510349739443
# 迷路を解くのにかかったステップ数は15です
# 0.016808936616917153
# 迷路を解くのにかかったステップ数は45です
# 0.011286703387846458
# 迷路を解くのにかかったステップ数は145です
# 0.010418061514420845
# 迷路を解くのにかかったステップ数は150です
# 0.016137480379141228
# 迷路を解くのにかかったステップ数は45です
# 0.01823721000204745
# 迷路を解くのにかかったステップ数は51です
# 0.010828370905953011
# 迷路を解くのにかかったステップ数は124です
# 0.015550940895281723
# 迷路を解くのにかかったステップ数は73です
# 0.03262590236024637
# 迷路を解くのにかかったステップ数は7です
# 0.03583068076987933
# 迷路を解くのにかかったステップ数は6です
# 0.011732241882486338
# 迷路を解くのにかかったステップ数は123です
# 0.019063317192049012
# 迷路を解くのにかかったステップ数は25です
# 0.0203568702851242
# 迷路を解くのにかかったステップ数は36です
# 0.009628429335608424
# 迷路を解くのにかかったステップ数は249です
# 0.015214803626324935
# 迷路を解くのにかかったステップ数は44です
# 0.024763161170128778
# 迷路を解くのにかかったステップ数は15です
# 0.01710271371650443
# 迷路を解くのにかかったステップ数は46です
# 0.010406362256305562
# 迷路を解くのにかかったステップ数は173です
# 0.02896385387121908
# 迷路を解くのにかかったステップ数は17です
# 0.013517700586765102
# 迷路を解くのにかかったステップ数は54です
# 0.02486804639568696
# 迷路を解くのにかかったステップ数は18です
# 0.011917287889247397
# 迷路を解くのにかかったステップ数は194です
# 0.018074606359792744
# 迷路を解くのにかかったステップ数は26です
# 0.013395500229537144
# 迷路を解くのにかかったステップ数は75です
# 0.019850643711541743
# 迷路を解くのにかかったステップ数は45です
# 0.020747488123418645
# 迷路を解くのにかかったステップ数は29です
# 0.009016798334699011
# 迷路を解くのにかかったステップ数は186です
# 0.02840662407479208
# 迷路を解くのにかかったステップ数は22です
# 0.02486078055670579
# 迷路を解くのにかかったステップ数は18です
# 0.027485479819980868
# 迷路を解くのにかかったステップ数は17です
# 0.03326437381894087
# 迷路を解くのにかかったステップ数は9です
# 0.013566972610920408
# 迷路を解くのにかかったステップ数は87です
# 0.009096542638906135
# 迷路を解くのにかかったステップ数は135です
# 0.012034689417574712
# 迷路を解くのにかかったステップ数は103です
# 0.01451836591596789
# 迷路を解くのにかかったステップ数は66です
# 0.038396990745414
# 迷路を解くのにかかったステップ数は5です
# 0.02016813096235856
# 迷路を解くのにかかったステップ数は40です
# 0.018122219750918905
# 迷路を解くのにかかったステップ数は45です
# 0.03689766734095806
# 迷路を解くのにかかったステップ数は8です
# 0.018568737362747112
# 迷路を解くのにかかったステップ数は35です
# 0.02204950999741284
# 迷路を解くのにかかったステップ数は35です
# 0.01876677377166741
# 迷路を解くのにかかったステップ数は33です
# 0.029025776495587824
# 迷路を解くのにかかったステップ数は14です
# 0.014518509157243509
# 迷路を解くのにかかったステップ数は72です
# 0.022021188692197713
# 迷路を解くのにかかったステップ数は44です
# 0.023853162059918998
# 迷路を解くのにかかったステップ数は34です
# 0.020150041910846905
# 迷路を解くのにかかったステップ数は30です
# 0.01377018368328109
# 迷路を解くのにかかったステップ数は69です
# 0.02045717622955756
# 迷路を解くのにかかったステップ数は38です
# 0.015582394789585258
# 迷路を解くのにかかったステップ数は32です
# 0.025705867307147356
# 迷路を解くのにかかったステップ数は35です
# 0.012078993039858932
# 迷路を解くのにかかったステップ数は142です
# 0.01066827936922568
# 迷路を解くのにかかったステップ数は149です
# 0.02636038917173389
# 迷路を解くのにかかったステップ数は24です
# 0.012730513815482458
# 迷路を解くのにかかったステップ数は112です
# 0.021246020207338095
# 迷路を解くのにかかったステップ数は33です
# 0.018922684264707362
# 迷路を解くのにかかったステップ数は38です
# 0.015181743089932115
# 迷路を解くのにかかったステップ数は119です
# 0.026887858378572715
# 迷路を解くのにかかったステップ数は19です
# 0.030321775347635388
# 迷路を解くのにかかったステップ数は13です
# 0.03452147922687496
# 迷路を解くのにかかったステップ数は9です
# 0.015605429614390959
# 迷路を解くのにかかったステップ数は42です
# 0.00972204695911097
# 迷路を解くのにかかったステップ数は291です
# 0.011424806066743176
# 迷路を解くのにかかったステップ数は100です
# 0.010083457789901829
# 迷路を解くのにかかったステップ数は130です
# 0.014216767633311173
# 迷路を解くのにかかったステップ数は54です
# 0.03207295554326192
# 迷路を解くのにかかったステップ数は9です
# 0.0361915950375315
# 迷路を解くのにかかったステップ数は5です
# 0.028222985760331526
# 迷路を解くのにかかったステップ数は15です
# 0.017016059787236165
# 迷路を解くのにかかったステップ数は55です
# 0.01858975738065352
# 迷路を解くのにかかったステップ数は63です
# 0.01076499677225276
# 迷路を解くのにかかったステップ数は125です
# 0.01627141246634345
# 迷路を解くのにかかったステップ数は30です
# 0.014337399161809428
# 迷路を解くのにかかったステップ数は61です
# 0.029658624955291146
# 迷路を解くのにかかったステップ数は13です
# 0.011736105552559523
# 迷路を解くのにかかったステップ数は139です
# 0.013772400963190712
# 迷路を解くのにかかったステップ数は77です
# 0.011019769924114797
# 迷路を解くのにかかったステップ数は182です
# 0.011472091842575749
# 迷路を解くのにかかったステップ数は122です
# 0.011575209562640049
# 迷路を解くのにかかったステップ数は134です
# 0.014347689238180195
# 迷路を解くのにかかったステップ数は79です
# 0.015353756147157588
# 迷路を解くのにかかったステップ数は71です
# 0.01358239336173206
# 迷路を解くのにかかったステップ数は93です
# 0.029328661779538856
# 迷路を解くのにかかったステップ数は12です
# 0.015949888167180015
# 迷路を解くのにかかったステップ数は54です
# 0.020847818025627074
# 迷路を解くのにかかったステップ数は39です
# 0.021383538589313328
# 迷路を解くのにかかったステップ数は24です
# 0.014323380301151573
# 迷路を解くのにかかったステップ数は60です
# 0.02442318495630927
# 迷路を解くのにかかったステップ数は20です
# 0.01634455034097268
# 迷路を解くのにかかったステップ数は65です
# 0.027937202764526436
# 迷路を解くのにかかったステップ数は17です
# 0.010933248656877781
# 迷路を解くのにかかったステップ数は144です
# 0.019626239838910348
# 迷路を解くのにかかったステップ数は34です
# 0.023941073755042563
# 迷路を解くのにかかったステップ数は21です
# 0.02338553852469874
# 迷路を解くのにかかったステップ数は24です
# 0.014141841083433221
# 迷路を解くのにかかったステップ数は34です
# 0.022185885475974026
# 迷路を解くのにかかったステップ数は14です
# 0.01667489631162067
# 迷路を解くのにかかったステップ数は32です
# 0.017030662711759736
# 迷路を解くのにかかったステップ数は32です
# 0.011324441232428872
# 迷路を解くのにかかったステップ数は89です
# 0.02142444531403201
# 迷路を解くのにかかったステップ数は23です
# 0.027736390232684316
# 迷路を解くのにかかったステップ数は21です
# 0.03729207536045501
# 迷路を解くのにかかったステップ数は8です
# 0.026753734736376045
# 迷路を解くのにかかったステップ数は14です
# 0.018147114701385303
# 迷路を解くのにかかったステップ数は47です
# 0.011608409126603297
# 迷路を解くのにかかったステップ数は132です
# 0.01965658284900651
# 迷路を解くのにかかったステップ数は30です
# 0.029099726992577346
# 迷路を解くのにかかったステップ数は20です
# 0.025670255904120698
# 迷路を解くのにかかったステップ数は19です
# 0.02709217318187801
# 迷路を解くのにかかったステップ数は19です
# 0.012931989311220887
# 迷路を解くのにかかったステップ数は102です
# 0.014237248150913429
# 迷路を解くのにかかったステップ数は80です
# 0.016986480435603052
# 迷路を解くのにかかったステップ数は48です
# 0.011325552200830119
# 迷路を解くのにかかったステップ数は118です
# 0.02485414228671537
# 迷路を解くのにかかったステップ数は29です
# 0.01593719494405199
# 迷路を解くのにかかったステップ数は50です
# 0.0244212332258959
# 迷路を解くのにかかったステップ数は19です
# 0.025995234036577913
# 迷路を解くのにかかったステップ数は12です
# 0.009951224374169954
# 迷路を解くのにかかったステップ数は186です
# 0.010815360013380598
# 迷路を解くのにかかったステップ数は113です
# 0.012642441241879576
# 迷路を解くのにかかったステップ数は115です
# 0.021142843724486937
# 迷路を解くのにかかったステップ数は32です
# 0.020346600195482067
# 迷路を解くのにかかったステップ数は42です
# 0.020520470436162258
# 迷路を解くのにかかったステップ数は35です
# 0.012229887651093868
# 迷路を解くのにかかったステップ数は147です
# 0.020497860125375245
# 迷路を解くのにかかったステップ数は18です
# 0.030333984959954596
# 迷路を解くのにかかったステップ数は20です
# 0.02257836811648431
# 迷路を解くのにかかったステップ数は30です
# 0.014054674357432961
# 迷路を解くのにかかったステップ数は56です
# 0.009649348856879014
# 迷路を解くのにかかったステップ数は166です
# 0.017145078392856505
# 迷路を解くのにかかったステップ数は35です
# 0.018172490430094473
# 迷路を解くのにかかったステップ数は78です
# 0.016806364962732856
# 迷路を解くのにかかったステップ数は41です
# 0.03857383520983598
# 迷路を解くのにかかったステップ数は6です
# 0.02321664310951338
# 迷路を解くのにかかったステップ数は30です
# 0.01892473794267935
# 迷路を解くのにかかったステップ数は33です
# 0.02978899458081677
# 迷路を解くのにかかったステップ数は13です
# 0.01342878072020573
# 迷路を解くのにかかったステップ数は105です
# 0.02854893530215505
# 迷路を解くのにかかったステップ数は14です
# 0.011118961298055258
# 迷路を解くのにかかったステップ数は96です
# 0.01849735029650612
# 迷路を解くのにかかったステップ数は37です
# 0.01597568378053596
# 迷路を解くのにかかったステップ数は52です
# 0.017272688973081513
# 迷路を解くのにかかったステップ数は42です
# 0.01597476908137982
# 迷路を解くのにかかったステップ数は63です
# 0.01729289132905179
# 迷路を解くのにかかったステップ数は78です
# 0.016030632325512717
# 迷路を解くのにかかったステップ数は23です
# 0.01628308927815439
# 迷路を解くのにかかったステップ数は42です
# 0.03484310041791416
# 迷路を解くのにかかったステップ数は8です
# 0.02136005208450062
# 迷路を解くのにかかったステップ数は31です
# 0.01079327478124631
# 迷路を解くのにかかったステップ数は182です
# 0.02072602834911963
# 迷路を解くのにかかったステップ数は43です
# 0.02716879028352881
# 迷路を解くのにかかったステップ数は13です
# 0.030158632934858348
# 迷路を解くのにかかったステップ数は13です
# 0.023964918148716013
# 迷路を解くのにかかったステップ数は39です
# 0.020427208286242227
# 迷路を解くのにかかったステップ数は40です
# 0.02962501761117428
# 迷路を解くのにかかったステップ数は22です
# 0.017911683262633787
# 迷路を解くのにかかったステップ数は36です
# 0.03123374838236026
# 迷路を解くのにかかったステップ数は8です
# 0.028773461592338456
# 迷路を解くのにかかったステップ数は18です
# 0.015728914448873282
# 迷路を解くのにかかったステップ数は51です
# 0.02231882559021206
# 迷路を解くのにかかったステップ数は28です
# 0.01361980854323902
# 迷路を解くのにかかったステップ数は87です
# 0.02145458184206231
# 迷路を解くのにかかったステップ数は31です
# 0.012193020369285323
# 迷路を解くのにかかったステップ数は89です
# 0.027927041496976113
# 迷路を解くのにかかったステップ数は13です
# 0.02190537475699017
# 迷路を解くのにかかったステップ数は33です
# 0.017412131845036843
# 迷路を解くのにかかったステップ数は48です
# 0.02191703836446618
# 迷路を解くのにかかったステップ数は39です
# 0.025136147119019847
# 迷路を解くのにかかったステップ数は14です
# 0.02438334990691174
# 迷路を解くのにかかったステップ数は19です
# 0.01707787765811633
# 迷路を解くのにかかったステップ数は70です
# 0.021421806333984023
# 迷路を解くのにかかったステップ数は42です
# 0.027757521668872742
# 迷路を解くのにかかったステップ数は18です
# 0.035048263745507735
# 迷路を解くのにかかったステップ数は5です
# 0.020123189169935912
# 迷路を解くのにかかったステップ数は38です
# 0.03037145393286128
# 迷路を解くのにかかったステップ数は12です
# 0.026218803391222595
# 迷路を解くのにかかったステップ数は34です
# 0.03414039560589502
# 迷路を解くのにかかったステップ数は11です
# 0.015237133615472465
# 迷路を解くのにかかったステップ数は64です
# 0.020714905909602482
# 迷路を解くのにかかったステップ数は25です
# 0.03272827673299267
# 迷路を解くのにかかったステップ数は13です
# 0.012484059657848962
# 迷路を解くのにかかったステップ数は133です
# 0.011297701422931017
# 迷路を解くのにかかったステップ数は79です
# 0.014465770254144389
# 迷路を解くのにかかったステップ数は63です
# 0.01685615697823925
# 迷路を解くのにかかったステップ数は49です
# 0.013709079061018814
# 迷路を解くのにかかったステップ数は81です
# 0.022026064293350522
# 迷路を解くのにかかったステップ数は22です
# 0.02368213444477893
# 迷路を解くのにかかったステップ数は24です
# 0.02787335409908226
# 迷路を解くのにかかったステップ数は12です
# 0.011787254254014473
# 迷路を解くのにかかったステップ数は160です
# 0.022394762240102367
# 迷路を解くのにかかったステップ数は27です
# 0.01459617048957984
# 迷路を解くのにかかったステップ数は90です
# 0.016579671210086022
# 迷路を解くのにかかったステップ数は40です
# 0.018820544340012735
# 迷路を解くのにかかったステップ数は48です
# 0.02762190456726943
# 迷路を解くのにかかったステップ数は13です
# 0.016097691174025153
# 迷路を解くのにかかったステップ数は79です
# 0.02454243631610259
# 迷路を解くのにかかったステップ数は12です
# 0.016668856612450933
# 迷路を解くのにかかったステップ数は46です
# 0.02576880687776359
# 迷路を解くのにかかったステップ数は24です
# 0.03673650056460956
# 迷路を解くのにかかったステップ数は8です
# 0.023480902193425524
# 迷路を解くのにかかったステップ数は30です
# 0.03154209118162893
# 迷路を解くのにかかったステップ数は9です
# 0.030994096624955836
# 迷路を解くのにかかったステップ数は8です
# 0.012689493833099669
# 迷路を解くのにかかったステップ数は112です
# 0.017106058146762138
# 迷路を解くのにかかったステップ数は42です
# 0.038619720659274465
# 迷路を解くのにかかったステップ数は4です
# 0.0215001580823522
# 迷路を解くのにかかったステップ数は26です
# 0.02673243829961708
# 迷路を解くのにかかったステップ数は24です
# 0.02309430242688268
# 迷路を解くのにかかったステップ数は33です
# 0.023945195709401873
# 迷路を解くのにかかったステップ数は32です
# 0.026514445145641635
# 迷路を解くのにかかったステップ数は24です
# 0.027557774840730215
# 迷路を解くのにかかったステップ数は17です
# 0.01120045821679308
# 迷路を解くのにかかったステップ数は132です
# 0.023366336609429245
# 迷路を解くのにかかったステップ数は18です
# 0.018511607126701024
# 迷路を解くのにかかったステップ数は32です
# 0.029817698481809624
# 迷路を解くのにかかったステップ数は10です
# 0.020291885995430775
# 迷路を解くのにかかったステップ数は35です
# 0.025224155461804676
# 迷路を解くのにかかったステップ数は23です
# 0.029913081297835015
# 迷路を解くのにかかったステップ数は15です
# 0.02729570590745828
# 迷路を解くのにかかったステップ数は27です
# 0.01773766290895254
# 迷路を解くのにかかったステップ数は40です
# 0.01198757381139623
# 迷路を解くのにかかったステップ数は87です
# 0.02632405208942687
# 迷路を解くのにかかったステップ数は23です
# 0.01099561229543397
# 迷路を解くのにかかったステップ数は111です
# 0.030237206824366397
# 迷路を解くのにかかったステップ数は12です
# 0.027192260970365728
# 迷路を解くのにかかったステップ数は22です
# 0.012533093780918325
# 迷路を解くのにかかったステップ数は70です
# 0.02854258247782282
# 迷路を解くのにかかったステップ数は14です
# 0.01861494293680821
# 迷路を解くのにかかったステップ数は35です
# 0.025936706825639144
# 迷路を解くのにかかったステップ数は25です
# 0.027740934371601772
# 迷路を解くのにかかったステップ数は14です
# 0.01564020743347308
# 迷路を解くのにかかったステップ数は74です
# 0.012448061917278375
# 迷路を解くのにかかったステップ数は80です
# 0.02661890396446223
# 迷路を解くのにかかったステップ数は19です
# 0.01452036856882627
# 迷路を解くのにかかったステップ数は67です
# 0.018523278529344128
# 迷路を解くのにかかったステップ数は29です
# 0.018376611594338454
# 迷路を解くのにかかったステップ数は22です
# 0.01713461555465179
# 迷路を解くのにかかったステップ数は41です
# 0.019287024620908533
# 迷路を解くのにかかったステップ数は31です
# 0.012455334647853838
# 迷路を解くのにかかったステップ数は75です
# 0.017609350471007923
# 迷路を解くのにかかったステップ数は50です
# 0.020269298394455654
# 迷路を解くのにかかったステップ数は32です
# 0.02583043199490523
# 迷路を解くのにかかったステップ数は16です
# 0.011404181326064022
# 迷路を解くのにかかったステップ数は120です
# 0.02656661835076604
# 迷路を解くのにかかったステップ数は11です
# 0.012092290645176001
# 迷路を解くのにかかったステップ数は120です
# 0.01519606117322067
# 迷路を解くのにかかったステップ数は61です
# 0.022337824343783286
# 迷路を解くのにかかったステップ数は33です
# 0.030263691546364796
# 迷路を解くのにかかったステップ数は10です
# 0.017093194758403124
# 迷路を解くのにかかったステップ数は49です
# 0.025888069030323008
# 迷路を解くのにかかったステップ数は16です
# 0.0221848385693052
# 迷路を解くのにかかったステップ数は33です
# 0.015355743631995128
# 迷路を解くのにかかったステップ数は69です
# 0.010566298788588668
# 迷路を解くのにかかったステップ数は107です
# 0.01705283417064965
# 迷路を解くのにかかったステップ数は42です
# 0.021357535622564566
# 迷路を解くのにかかったステップ数は44です
# 0.013289420441245453
# 迷路を解くのにかかったステップ数は97です
# 0.02882645829810082
# 迷路を解くのにかかったステップ数は8です
# 0.0320627552071259
# 迷路を解くのにかかったステップ数は12です
# 0.019251693363641104
# 迷路を解くのにかかったステップ数は26です
# 0.03691999586922812
# 迷路を解くのにかかったステップ数は6です
# 0.021687573845909275
# 迷路を解くのにかかったステップ数は16です
# 0.01473684829616112
# 迷路を解くのにかかったステップ数は99です
# 0.0346085182841514
# 迷路を解くのにかかったステップ数は10です
# 0.014019455895115884
# 迷路を解くのにかかったステップ数は73です
# 0.01181441468884964
# 迷路を解くのにかかったステップ数は71です
# 0.016154870806813992
# 迷路を解くのにかかったステップ数は70です
# 0.014934784789957828
# 迷路を解くのにかかったステップ数は73です
# 0.015119510596489777
# 迷路を解くのにかかったステップ数は60です
# 0.02760645297655226
# 迷路を解くのにかかったステップ数は23です
# 0.02560694412886902
# 迷路を解くのにかかったステップ数は25です
# 0.033313261632400615
# 迷路を解くのにかかったステップ数は7です
# 0.03056963437128682
# 迷路を解くのにかかったステップ数は10です
# 0.02347454952831507
# 迷路を解くのにかかったステップ数は31です
# 0.015070104000701412
# 迷路を解くのにかかったステップ数は39です
# 0.022166189163722594
# 迷路を解くのにかかったステップ数は26です
# 0.030473082276872232
# 迷路を解くのにかかったステップ数は9です
# 0.015532445653189703
# 迷路を解くのにかかったステップ数は73です
# 0.014641436107571792
# 迷路を解くのにかかったステップ数は76です
# 0.013820779354157042
# 迷路を解くのにかかったステップ数は56です
# 0.031326714500017505
# 迷路を解くのにかかったステップ数は9です
# 0.014419202777424617
# 迷路を解くのにかかったステップ数は47です
# 0.019355276845477054
# 迷路を解くのにかかったステップ数は24です
# 0.037338970489353446
# 迷路を解くのにかかったステップ数は10です
# 0.015559217898242633
# 迷路を解くのにかかったステップ数は46です
# 0.012740513112638685
# 迷路を解くのにかかったステップ数は83です
# 0.017593552713655092
# 迷路を解くのにかかったステップ数は44です
# 0.030466639327023648
# 迷路を解くのにかかったステップ数は11です
# 0.02970991659926492
# 迷路を解くのにかかったステップ数は11です
# 0.019635245628623954
# 迷路を解くのにかかったステップ数は46です
# 0.02153523265812915
# 迷路を解くのにかかったステップ数は35です
# 0.012202696217633008
# 迷路を解くのにかかったステップ数は102です
# 0.020110979629680115
# 迷路を解くのにかかったステップ数は52です
# 0.022170764131503234
# 迷路を解くのにかかったステップ数は33です
# 0.02674600243117506
# 迷路を解くのにかかったステップ数は15です
# 0.038970724354039255
# 迷路を解くのにかかったステップ数は5です
# 0.023483966538832834
# 迷路を解くのにかかったステップ数は26です
# 0.03109275661753111
# 迷路を解くのにかかったステップ数は10です
# 0.024327688001955616
# 迷路を解くのにかかったステップ数は29です
# 0.028691588378711386
# 迷路を解くのにかかったステップ数は17です
# 0.015630005718768714
# 迷路を解くのにかかったステップ数は69です
# 0.032250711079879535
# 迷路を解くのにかかったステップ数は9です
# 0.0310058504159976
# 迷路を解くのにかかったステップ数は7です
# 0.03918801965900137
# 迷路を解くのにかかったステップ数は4です
# 0.02118837764562337
# 迷路を解くのにかかったステップ数は29です
# 0.015021881922002989
# 迷路を解くのにかかったステップ数は81です
# 0.012995763143150457
# 迷路を解くのにかかったステップ数は100です
# 0.017288770336722825
# 迷路を解くのにかかったステップ数は29です
# 0.019883534534090058
# 迷路を解くのにかかったステップ数は34です
# 0.021726620407879454
# 迷路を解くのにかかったステップ数は18です
# 0.01763056410068467
# 迷路を解くのにかかったステップ数は44です
# 0.009871960571745914
# 迷路を解くのにかかったステップ数は171です
# 0.020548753357553462
# 迷路を解くのにかかったステップ数は49です
# 0.01169707560095376
# 迷路を解くのにかかったステップ数は87です
# 0.017030888938166483
# 迷路を解くのにかかったステップ数は44です
# 0.011342102033625762
# 迷路を解くのにかかったステップ数は115です
# 0.01502389188545808
# 迷路を解くのにかかったステップ数は54です
# 0.03327086764456916
# 迷路を解くのにかかったステップ数は9です
# 0.01725933643737046
# 迷路を解くのにかかったステップ数は60です
# 0.02584895382770111
# 迷路を解くのにかかったステップ数は14です
# 0.028164389266492423
# 迷路を解くのにかかったステップ数は9です
# 0.019806767914299833
# 迷路を解くのにかかったステップ数は22です
# 0.02633070905381532
# 迷路を解くのにかかったステップ数は13です
# 0.016655179340330617
# 迷路を解くのにかかったステップ数は83です
# 0.01169981165146497
# 迷路を解くのにかかったステップ数は109です
# 0.011807664181071043
# 迷路を解くのにかかったステップ数は59です
# 0.03864832031936269
# 迷路を解くのにかかったステップ数は7です
# 0.01735133323968238
# 迷路を解くのにかかったステップ数は25です
# 0.017397388003350556
# 迷路を解くのにかかったステップ数は58です
# 0.0224847988142379
# 迷路を解くのにかかったステップ数は23です
# 0.020240308054944922
# 迷路を解くのにかかったステップ数は24です
# 0.014766931440253872
# 迷路を解くのにかかったステップ数は97です
# 0.022865248511770353
# 迷路を解くのにかかったステップ数は20です
# 0.03337247528301279
# 迷路を解くのにかかったステップ数は7です
# 0.022852740123933457
# 迷路を解くのにかかったステップ数は22です
# 0.024911087543828203
# 迷路を解くのにかかったステップ数は11です
# 0.02060841705656924
# 迷路を解くのにかかったステップ数は31です
# 0.030417385539500214
# 迷路を解くのにかかったステップ数は18です
# 0.012027637581541323
# 迷路を解くのにかかったステップ数は62です
# 0.039310977320418106
# 迷路を解くのにかかったステップ数は4です
# 0.013756473857948925
# 迷路を解くのにかかったステップ数は100です
# 0.03125212991985887
# 迷路を解くのにかかったステップ数は7です
# 0.014356629437209611
# 迷路を解くのにかかったステップ数は68です
# 0.024113098880209738
# 迷路を解くのにかかったステップ数は15です
# 0.019479097592880745
# 迷路を解くのにかかったステップ数は42です
# 0.024480815195788957
# 迷路を解くのにかかったステップ数は19です
# 0.021780308020470512
# 迷路を解くのにかかったステップ数は19です
# 0.01625437009531247
# 迷路を解くのにかかったステップ数は41です
# 0.01653637836585592
# 迷路を解くのにかかったステップ数は39です
# 0.01845631629795308
# 迷路を解くのにかかったステップ数は45です
# 0.023664857528557154
# 迷路を解くのにかかったステップ数は21です
# 0.02964890082834698
# 迷路を解くのにかかったステップ数は9です
# 0.025929459613885403
# 迷路を解くのにかかったステップ数は18です
# 0.015295720100334087
# 迷路を解くのにかかったステップ数は92です
# 0.03901764478215669
# 迷路を解くのにかかったステップ数は6です
# 0.01627641163612073
# 迷路を解くのにかかったステップ数は42です
# 0.019264718285887078
# 迷路を解くのにかかったステップ数は29です
# 0.018299269146104052
# 迷路を解くのにかかったステップ数は61です
# 0.029591566444485073
# 迷路を解くのにかかったステップ数は18です
# 0.0122855558621085
# 迷路を解くのにかかったステップ数は67です
# 0.02497227860721199
# 迷路を解くのにかかったステップ数は12です
# 0.029952945220750038
# 迷路を解くのにかかったステップ数は12です
# 0.020252343330852712
# 迷路を解くのにかかったステップ数は25です
# 0.013981430326937633
# 迷路を解くのにかかったステップ数は58です
# 0.02202150063548064
# 迷路を解くのにかかったステップ数は32です
# 0.01457784108943927
# 迷路を解くのにかかったステップ数は77です
# 0.025506837271689314
# 迷路を解くのにかかったステップ数は16です
# 0.03733669560817879
# 迷路を解くのにかかったステップ数は8です
# 0.014890342550427732
# 迷路を解くのにかかったステップ数は88です
# 0.02540460572005257
# 迷路を解くのにかかったステップ数は10です
# 0.023972632208468014
# 迷路を解くのにかかったステップ数は22です
# 0.012531668421977199
# 迷路を解くのにかかったステップ数は48です
# 0.037697130813203666
# 迷路を解くのにかかったステップ数は7です
# 0.020772990059312685
# 迷路を解くのにかかったステップ数は23です
# 0.03375581646727707
# 迷路を解くのにかかったステップ数は7です
# 0.023443214109617444
# 迷路を解くのにかかったステップ数は24です
# 0.01668357326484768
# 迷路を解くのにかかったステップ数は50です
# 0.011490304592794681
# 迷路を解くのにかかったステップ数は96です
# 0.017300748342093136
# 迷路を解くのにかかったステップ数は24です
# 0.028649941982993782
# 迷路を解くのにかかったステップ数は11です
# 0.024753429690818535
# 迷路を解くのにかかったステップ数は19です
# 0.023164787407078558
# 迷路を解くのにかかったステップ数は22です
# 0.017899778301492725
# 迷路を解くのにかかったステップ数は18です
# 0.02708372936383724
# 迷路を解くのにかかったステップ数は14です
# 0.02219807894542014
# 迷路を解くのにかかったステップ数は26です
# 0.020929034534114127
# 迷路を解くのにかかったステップ数は17です
# 0.038070672884263856
# 迷路を解くのにかかったステップ数は6です
# 0.0181123563659861
# 迷路を解くのにかかったステップ数は47です
# 0.03109289495049189
# 迷路を解くのにかかったステップ数は17です
# 0.024855853788572496
# 迷路を解くのにかかったステップ数は13です
# 0.02582304313882619
# 迷路を解くのにかかったステップ数は11です
# 0.020374474060621484
# 迷路を解くのにかかったステップ数は28です
# 0.014494267379860454
# 迷路を解くのにかかったステップ数は44です
# 0.02523615788807554
# 迷路を解くのにかかったステップ数は11です
# 0.025134086373243214
# 迷路を解くのにかかったステップ数は17です
# 0.0203706255362274
# 迷路を解くのにかかったステップ数は37です
# 0.023832625336561414
# 迷路を解くのにかかったステップ数は31です
# 0.03876407707704843
# 迷路を解くのにかかったステップ数は5です
# 0.013669471575685377
# 迷路を解くのにかかったステップ数は82です
# 0.025945695456847134
# 迷路を解くのにかかったステップ数は21です
# 0.025828148393552963
# 迷路を解くのにかかったステップ数は30です
# 0.026627913922481983
# 迷路を解くのにかかったステップ数は24です
# 0.038270760988795366
# 迷路を解くのにかかったステップ数は5です
# 0.03375877199958141
# 迷路を解くのにかかったステップ数は8です
# 0.013109778438837594
# 迷路を解くのにかかったステップ数は141です
# 0.03149411159825927
# 迷路を解くのにかかったステップ数は11です
# 0.02625690470248715
# 迷路を解くのにかかったステップ数は19です
# 0.018922586593985158
# 迷路を解くのにかかったステップ数は41です
# 0.0319418615100778
# 迷路を解くのにかかったステップ数は12です
# 0.03341170018421416
# 迷路を解くのにかかったステップ数は9です
# 0.018921854617846928
# 迷路を解くのにかかったステップ数は44です
# 0.02785537429828558
# 迷路を解くのにかかったステップ数は17です
# 0.024315997458534994
# 迷路を解くのにかかったステップ数は34です
# 0.0166181600108585
# 迷路を解くのにかかったステップ数は65です
# 0.029077086418664883
# 迷路を解くのにかかったステップ数は13です
# 0.023073034811504328
# 迷路を解くのにかかったステップ数は17です
# 0.023104294491539445
# 迷路を解くのにかかったステップ数は17です
# 0.033919588239736315
# 迷路を解くのにかかったステップ数は9です
# 0.01993832952153035
# 迷路を解くのにかかったステップ数は36です
# 0.013470341501874566
# 迷路を解くのにかかったステップ数は92です
# 0.017088500471255152
# 迷路を解くのにかかったステップ数は52です
# 0.027255561706728215
# 迷路を解くのにかかったステップ数は26です
# 0.0379700778510379
# 迷路を解くのにかかったステップ数は6です
# 0.02833595588041926
# 迷路を解くのにかかったステップ数は15です
# 0.021134845718682627
# 迷路を解くのにかかったステップ数は20です
# 0.025441365192633514
# 迷路を解くのにかかったステップ数は24です
# 0.015011215202332978
# 迷路を解くのにかかったステップ数は75です
# 0.020067970520321166
# 迷路を解くのにかかったステップ数は16です
# 0.017730214827974017
# 迷路を解くのにかかったステップ数は50です
# 0.021945023323982904
# 迷路を解くのにかかったステップ数は30です
# 0.016855370597867403
# 迷路を解くのにかかったステップ数は54です
# 0.016779736815727336
# 迷路を解くのにかかったステップ数は52です
# 0.03287604796383828
# 迷路を解くのにかかったステップ数は13です
# 0.021919402317071957
# 迷路を解くのにかかったステップ数は36です
# 0.022255308168171145
# 迷路を解くのにかかったステップ数は20です
# 0.018213636121290816
# 迷路を解くのにかかったステップ数は33です
# 0.013789666968512831
# 迷路を解くのにかかったステップ数は103です
# 0.026895182654062766
# 迷路を解くのにかかったステップ数は14です
# 0.018134993014179507
# 迷路を解くのにかかったステップ数は40です
# 0.01911435130854655
# 迷路を解くのにかかったステップ数は30です
# 0.02476983740044439
# 迷路を解くのにかかったステップ数は33です
# 0.015421896643157545
# 迷路を解くのにかかったステップ数は65です
# 0.02802050506862705
# 迷路を解くのにかかったステップ数は23です
# 0.03514381731758365
# 迷路を解くのにかかったステップ数は11です
# 0.028166910762039893
# 迷路を解くのにかかったステップ数は12です
# 0.01772982958780145
# 迷路を解くのにかかったステップ数は36です
# 0.02860740662145489
# 迷路を解くのにかかったステップ数は14です
# 0.014867570786358086
# 迷路を解くのにかかったステップ数は56です
# 0.029125036695479112
# 迷路を解くのにかかったステップ数は17です
# 0.012862588767112326
# 迷路を解くのにかかったステップ数は104です
# 0.02390228013348361
# 迷路を解くのにかかったステップ数は22です
# 0.026709833368711217
# 迷路を解くのにかかったステップ数は20です
# 0.02295093746675636
# 迷路を解くのにかかったステップ数は14です
# 0.030095285800567223
# 迷路を解くのにかかったステップ数は9です
# 0.02916157041528314
# 迷路を解くのにかかったステップ数は11です
# 0.016309908976778364
# 迷路を解くのにかかったステップ数は47です
# 0.01806541445612672
# 迷路を解くのにかかったステップ数は44です
# 0.023933166360036923
# 迷路を解くのにかかったステップ数は32です
# 0.02773939027747732
# 迷路を解くのにかかったステップ数は10です
# 0.030347246623635693
# 迷路を解くのにかかったステップ数は8です
# 0.02946702630943493
# 迷路を解くのにかかったステップ数は19です
# 0.03836076479328385
# 迷路を解くのにかかったステップ数は7です
# 0.02211764488606724
# 迷路を解くのにかかったステップ数は25です
# 0.023572086119499208
# 迷路を解くのにかかったステップ数は31です
# 0.022545026790457806
# 迷路を解くのにかかったステップ数は23です
# 0.03095198979089947
# 迷路を解くのにかかったステップ数は10です
# 0.02085140281316039
# 迷路を解くのにかかったステップ数は9です
# 0.014295788327838066
# 迷路を解くのにかかったステップ数は70です
# 0.01810852796898535
# 迷路を解くのにかかったステップ数は34です
# 0.023257159122681892
# 迷路を解くのにかかったステップ数は26です
# 0.03929689922855942
# 迷路を解くのにかかったステップ数は4です
# 0.021232271822130833
# 迷路を解くのにかかったステップ数は31です
# 0.022439457624948728
# 迷路を解くのにかかったステップ数は22です
# 0.018829491432553858
# 迷路を解くのにかかったステップ数は56です
# 0.017563216735453052
# 迷路を解くのにかかったステップ数は41です
# 0.015815949432723464
# 迷路を解くのにかかったステップ数は62です
# 0.019381909817664078
# 迷路を解くのにかかったステップ数は53です
# 0.019467934023762845
# 迷路を解くのにかかったステップ数は23です
# 0.03925500164011925
# 迷路を解くのにかかったステップ数は5です
# 0.015426098171557517
# 迷路を解くのにかかったステップ数は30です
# 0.015797937129153117
# 迷路を解くのにかかったステップ数は53です
# 0.01875433469783247
# 迷路を解くのにかかったステップ数は17です
# 0.02540497703528735
# 迷路を解くのにかかったステップ数は15です
# 0.02187181951765335
# 迷路を解くのにかかったステップ数は32です
# 0.03106106822188981
# 迷路を解くのにかかったステップ数は10です
# 0.013836437755556596
# 迷路を解くのにかかったステップ数は53です
# 0.028334975739062296
# 迷路を解くのにかかったステップ数は7です
# 0.013834620599675884
# 迷路を解くのにかかったステップ数は85です
# 0.02396523080370569
# 迷路を解くのにかかったステップ数は24です
# 0.036358091211927485
# 迷路を解くのにかかったステップ数は8です
# 0.022175708392647653
# 迷路を解くのにかかったステップ数は31です
# 0.01571896725496319
# 迷路を解くのにかかったステップ数は40です
# 0.02868081201827838
# 迷路を解くのにかかったステップ数は11です
# 0.028618430091530117
# 迷路を解くのにかかったステップ数は8です
# 0.02031582359752407
# 迷路を解くのにかかったステップ数は22です
# 0.018649301611057878
# 迷路を解くのにかかったステップ数は50です
# 0.029419865112260718
# 迷路を解くのにかかったステップ数は13です
# 0.039212591704524596
# 迷路を解くのにかかったステップ数は4です
# 0.03407949431770249
# 迷路を解くのにかかったステップ数は6です
# 0.02227262157261492
# 迷路を解くのにかかったステップ数は22です
# 0.03912228105074153
# 迷路を解くのにかかったステップ数は4です
# 0.03132080466914189
# 迷路を解くのにかかったステップ数は9です
# 0.02975059121144688
# 迷路を解くのにかかったステップ数は9です
# 0.01467765299449017
# 迷路を解くのにかかったステップ数は74です
# 0.025719826099647597
# 迷路を解くのにかかったステップ数は13です
# 0.039055728998997674
# 迷路を解くのにかかったステップ数は4です
# 0.026666798071837194
# 迷路を解くのにかかったステップ数は21です
# 0.026117842616622255
# 迷路を解くのにかかったステップ数は16です
# 0.022032913752615596
# 迷路を解くのにかかったステップ数は31です
# 0.029780308147722312
# 迷路を解くのにかかったステップ数は9です
# 0.02277822836188989
# 迷路を解くのにかかったステップ数は33です
# 0.025458431093591638
# 迷路を解くのにかかったステップ数は24です
# 0.019820869049283513
# 迷路を解くのにかかったステップ数は28です
# 0.02920765908034656
# 迷路を解くのにかかったステップ数は8です
# 0.02818274088028236
# 迷路を解くのにかかったステップ数は19です
# 0.01768174389460389
# 迷路を解くのにかかったステップ数は41です
# 0.026575571305687606
# 迷路を解くのにかかったステップ数は27です
# 0.030795630394369278
# 迷路を解くのにかかったステップ数は12です
# 0.02661751906201515
# 迷路を解くのにかかったステップ数は14です
# 0.030386341271529727
# 迷路を解くのにかかったステップ数は10です
# 0.03794640981217115
# 迷路を解くのにかかったステップ数は6です
# 0.017350084512316677
# 迷路を解くのにかかったステップ数は46です
# 0.01649327104556439
# 迷路を解くのにかかったステップ数は67です
# 0.02057916324143752
# 迷路を解くのにかかったステップ数は47です
# 0.033797748619753126
# 迷路を解くのにかかったステップ数は9です
# 0.02356092926976469
# 迷路を解くのにかかったステップ数は31です
# 0.02951641743728403
# 迷路を解くのにかかったステップ数は13です
# 0.014429584715189292
# 迷路を解くのにかかったステップ数は66です
# 0.027185441284966416
# 迷路を解くのにかかったステップ数は23です
# 0.018770404264078472
# 迷路を解くのにかかったステップ数は35です
# 0.01647011145512997
# 迷路を解くのにかかったステップ数は64です
# 0.01964020057483898
# 迷路を解くのにかかったステップ数は40です
# 0.016557648967636313
# 迷路を解くのにかかったステップ数は74です
# 0.024060413356140176
# 迷路を解くのにかかったステップ数は18です
# 0.022867276897914207
# 迷路を解くのにかかったステップ数は27です
# 0.02065169795282157
# 迷路を解くのにかかったステップ数は18です
# 0.0312653309459959
# 迷路を解くのにかかったステップ数は7です
# 0.017176775213359557
# 迷路を解くのにかかったステップ数は50です
# 0.03083107754343134
# 迷路を解くのにかかったステップ数は6です
# 0.0222375795453158
# 迷路を解くのにかかったステップ数は48です
# 0.03272534618838141
# 迷路を解くのにかかったステップ数は8です
# 0.026017548108714428
# 迷路を解くのにかかったステップ数は8です
# 0.019769515557206713
# 迷路を解くのにかかったステップ数は21です
# 0.016232230556526422
# 迷路を解くのにかかったステップ数は38です
# 0.036887649469714734
# 迷路を解くのにかかったステップ数は7です
# 0.027081488774077733
# 迷路を解くのにかかったステップ数は7です
# 0.03647156415790068
# 迷路を解くのにかかったステップ数は5です
# 0.019580475759496785
# 迷路を解くのにかかったステップ数は44です
# 0.013248758709007102
# 迷路を解くのにかかったステップ数は59です
# 0.025493546312824134
# 迷路を解くのにかかったステップ数は14です
# 0.016903443400681673
# 迷路を解くのにかかったステップ数は44です
# 0.03674362649139326
# 迷路を解くのにかかったステップ数は9です
# 0.020358899074012282
# 迷路を解くのにかかったステップ数は31です
# 0.01858080029186257
# 迷路を解くのにかかったステップ数は39です
# 0.02014354213108821
# 迷路を解くのにかかったステップ数は40です
# 0.03691944209178891
# 迷路を解くのにかかったステップ数は5です
# 0.03861806662410702
# 迷路を解くのにかかったステップ数は4です
# 0.01781585731005228
# 迷路を解くのにかかったステップ数は62です
# 0.023623645551859335
# 迷路を解くのにかかったステップ数は12です
# 0.03280498634526152
# 迷路を解くのにかかったステップ数は12です
# 0.02407885222036779
# 迷路を解くのにかかったステップ数は22です
# 0.03828602606702078
# 迷路を解くのにかかったステップ数は5です
# 0.03954137823737933
# 迷路を解くのにかかったステップ数は5です
# 0.02261776306801419
# 迷路を解くのにかかったステップ数は20です
# 0.03218037252575942
# 迷路を解くのにかかったステップ数は8です
# 0.02046598066155647
# 迷路を解くのにかかったステップ数は39です
# 0.02339282101731774
# 迷路を解くのにかかったステップ数は26です
# 0.03465916848612277
# 迷路を解くのにかかったステップ数は7です
# 0.021369178806912525
# 迷路を解くのにかかったステップ数は38です
# 0.0275976733632958
# 迷路を解くのにかかったステップ数は15です
# 0.01967313256058592
# 迷路を解くのにかかったステップ数は41です
# 0.018760673076887002
# 迷路を解くのにかかったステップ数は41です
# 0.023175236952869854
# 迷路を解くのにかかったステップ数は29です
# 0.038478860218618044
# 迷路を解くのにかかったステップ数は4です
# 0.016181258731683995
# 迷路を解くのにかかったステップ数は52です
# 0.025694577409740738
# 迷路を解くのにかかったステップ数は8です
# 0.018837627947436153
# 迷路を解くのにかかったステップ数は21です
# 0.018168936506415212
# 迷路を解くのにかかったステップ数は40です
# 0.027732532153623923
# 迷路を解くのにかかったステップ数は13です
# 0.027405495136023583
# 迷路を解くのにかかったステップ数は20です
# 0.03967513993377628
# 迷路を解くのにかかったステップ数は5です
# 0.03179836913844189
# 迷路を解くのにかかったステップ数は7です
# 0.02278045643059759
# 迷路を解くのにかかったステップ数は31です
# 0.021215109935755677
# 迷路を解くのにかかったステップ数は19です
# 0.03227573764014238
# 迷路を解くのにかかったステップ数は6です
# 0.03282885608353425
# 迷路を解くのにかかったステップ数は6です
# 0.014446055740170632
# 迷路を解くのにかかったステップ数は50です
# 0.02269231773659197
# 迷路を解くのにかかったステップ数は16です
# 0.017456719441909185
# 迷路を解くのにかかったステップ数は19です
# 0.03795088725614462
# 迷路を解くのにかかったステップ数は5です
# 0.03742563339178512
# 迷路を解くのにかかったステップ数は6です
# 0.025643690607109526
# 迷路を解くのにかかったステップ数は15です
# 0.01855564372373339
# 迷路を解くのにかかったステップ数は31です
# 0.01845847665242173
# 迷路を解くのにかかったステップ数は63です
# 0.017250076072388987
# 迷路を解くのにかかったステップ数は36です
# 0.01895769792520774
# 迷路を解くのにかかったステップ数は30です
# 0.025521408131677137
# 迷路を解くのにかかったステップ数は22です
# 0.02663381974276441
# 迷路を解くのにかかったステップ数は19です
# 0.02409909522824419
# 迷路を解くのにかかったステップ数は21です
# 0.023673637748288595
# 迷路を解くのにかかったステップ数は11です
# 0.030742559410499415
# 迷路を解くのにかかったステップ数は7です
# 0.02721026546699362
# 迷路を解くのにかかったステップ数は11です
# 0.014110224411429284
# 迷路を解くのにかかったステップ数は87です
# 0.029729251535184964
# 迷路を解くのにかかったステップ数は6です
# 0.021491719250629815
# 迷路を解くのにかかったステップ数は27です
# 0.021943485583984346
# 迷路を解くのにかかったステップ数は15です
# 0.021462332014382662
# 迷路を解くのにかかったステップ数は28です
# 0.027927714818360788
# 迷路を解くのにかかったステップ数は15です
# 0.02529708073559686
# 迷路を解くのにかかったステップ数は22です
# 0.020584500677336443
# 迷路を解くのにかかったステップ数は19です
# 0.01750887149362576
# 迷路を解くのにかかったステップ数は36です
# 0.021727114003721515
# 迷路を解くのにかかったステップ数は23です
# 0.013538710434467555
# 迷路を解くのにかかったステップ数は95です
# 0.03222500816702184
# 迷路を解くのにかかったステップ数は11です
# 0.01748348467479932
# 迷路を解くのにかかったステップ数は70です
# 0.022464336279705677
# 迷路を解くのにかかったステップ数は15です
# 0.018325816459134975
# 迷路を解くのにかかったステップ数は51です
# 0.02402321206054925
# 迷路を解くのにかかったステップ数は22です
# 0.02226088250445099
# 迷路を解くのにかかったステップ数は24です
# 0.021063340239663025
# 迷路を解くのにかかったステップ数は22です
# 0.023564100742321487
# 迷路を解くのにかかったステップ数は41です
# 0.03785836681900878
# 迷路を解くのにかかったステップ数は4です
# 0.011510457591077466
# 迷路を解くのにかかったステップ数は119です
# 0.02166498823165733
# 迷路を解くのにかかったステップ数は17です
# 0.025717942871668564
# 迷路を解くのにかかったステップ数は22です
# 0.030872237978555733
# 迷路を解くのにかかったステップ数は10です
# 0.03343334494265238
# 迷路を解くのにかかったステップ数は8です
# 0.021658708493247608
# 迷路を解くのにかかったステップ数は33です
# 0.020213862352427975
# 迷路を解くのにかかったステップ数は35です
# 0.03630743001584322
# 迷路を解くのにかかったステップ数は11です
# 0.03224999381302207
# 迷路を解くのにかかったステップ数は7です
# 0.023933029467449046
# 迷路を解くのにかかったステップ数は17です
# 0.01951910922103095
# 迷路を解くのにかかったステップ数は28です
# 0.038208905327170334
# 迷路を解くのにかかったステップ数は5です
# 0.026126925058168243
# 迷路を解くのにかかったステップ数は13です
# 0.030251487976374974
# 迷路を解くのにかかったステップ数は7です
# 0.022717224924679758
# 迷路を解くのにかかったステップ数は23です
# 0.034360313673608006
# 迷路を解くのにかかったステップ数は8です
# 0.02394432595015722
# 迷路を解くのにかかったステップ数は11です
# 0.03556200310151708
# 迷路を解くのにかかったステップ数は6です
# 0.023849536150078565
# 迷路を解くのにかかったステップ数は23です
# 0.020013899299654053
# 迷路を解くのにかかったステップ数は27です
# 0.03179051895496002
# 迷路を解くのにかかったステップ数は9です
# 0.01652867017476553
# 迷路を解くのにかかったステップ数は70です
# 0.02996918544955071
# 迷路を解くのにかかったステップ数は15です
# 0.030994073137263628
# 迷路を解くのにかかったステップ数は9です
# 0.0376225723872729
# 迷路を解くのにかかったステップ数は5です
# 0.025811807169077272
# 迷路を解くのにかかったステップ数は19です
# 0.013817054712095794
# 迷路を解くのにかかったステップ数は78です
# 0.030134629470719237
# 迷路を解くのにかかったステップ数は12です
# 0.022825316816136337
# 迷路を解くのにかかったステップ数は23です
# 0.020712413107032007
# 迷路を解くのにかかったステップ数は27です
# 0.018566706902751973
# 迷路を解くのにかかったステップ数は21です
# 0.02496758346626185
# 迷路を解くのにかかったステップ数は16です
# 0.024669323212665795
# 迷路を解くのにかかったステップ数は12です
# 0.02338702777585963
# 迷路を解くのにかかったステップ数は30です
# 0.0294920728960128
# 迷路を解くのにかかったステップ数は11です
# 0.03489261759403045
# 迷路を解くのにかかったステップ数は7です
# 0.034793683912878876
# 迷路を解くのにかかったステップ数は7です
# 0.016269777889190845
# 迷路を解くのにかかったステップ数は74です
# 0.02644016585146708
# 迷路を解くのにかかったステップ数は18です
# 0.029113137948610507
# 迷路を解くのにかかったステップ数は13です
# 0.027890094236523832
# 迷路を解くのにかかったステップ数は21です
# 0.02898578687663589
# 迷路を解くのにかかったステップ数は15です
# 0.023031159252121014
# 迷路を解くのにかかったステップ数は24です
# 0.01868169881722187
# 迷路を解くのにかかったステップ数は39です
# 0.030095886606264305
# 迷路を解くのにかかったステップ数は14です
# 0.031963132277122
# 迷路を解くのにかかったステップ数は9です
# 0.02650295800192029
# 迷路を解くのにかかったステップ数は17です
# 0.03580169787519674
# 迷路を解くのにかかったステップ数は11です
# 0.024719966141544175
# 迷路を解くのにかかったステップ数は26です
# 0.025003206006895984
# 迷路を解くのにかかったステップ数は15です
# 0.03733291138230768
# 迷路を解くのにかかったステップ数は4です
# 0.020504633969501918
# 迷路を解くのにかかったステップ数は32です
# 0.033090241684438665
# 迷路を解くのにかかったステップ数は8です
# 0.015579807631693449
# 迷路を解くのにかかったステップ数は46です
# 0.02033408989793717
# 迷路を解くのにかかったステップ数は39です
# 0.022186309371022284
# 迷路を解くのにかかったステップ数は22です
# 0.02528404620833491
# 迷路を解くのにかかったステップ数は34です
# 0.036546241635183496
# 迷路を解くのにかかったステップ数は6です
# 0.030034829058306872
# 迷路を解くのにかかったステップ数は13です
# 0.024566796915231115
# 迷路を解くのにかかったステップ数は22です
# 0.01891282634389188
# 迷路を解くのにかかったステップ数は39です
# 0.0259190859112855
# 迷路を解くのにかかったステップ数は16です
# 0.029352170934615868
# 迷路を解くのにかかったステップ数は8です
# 0.02088043884425858
# 迷路を解くのにかかったステップ数は33です
# 0.023622784385166462
# 迷路を解くのにかかったステップ数は24です
# 0.025239561118218956
# 迷路を解くのにかかったステップ数は21です
# 0.03714922556525463
# 迷路を解くのにかかったステップ数は4です
# 0.03187103364715946
# 迷路を解くのにかかったステップ数は7です
# 0.02529363873571297
# 迷路を解くのにかかったステップ数は15です
# 0.021041060909163134
# 迷路を解くのにかかったステップ数は14です
# 0.026714441630018126
# 迷路を解くのにかかったステップ数は8です
# 0.017668779481081587
# 迷路を解くのにかかったステップ数は35です
# 0.031368121469261545
# 迷路を解くのにかかったステップ数は9です
# 0.02756991400637665
# 迷路を解くのにかかったステップ数は10です
# 0.03683869342571888
# 迷路を解くのにかかったステップ数は4です
# 0.013154537345643619
# 迷路を解くのにかかったステップ数は25です
# 0.021231418267777802
# 迷路を解くのにかかったステップ数は15です
# 0.03316645691137782
# 迷路を解くのにかかったステップ数は9です
# 0.030790981327295575
# 迷路を解くのにかかったステップ数は6です
# 0.02969171472232726
# 迷路を解くのにかかったステップ数は6です
# 0.02940982348781876
# 迷路を解くのにかかったステップ数は7です
# 0.019319707282650644
# 迷路を解くのにかかったステップ数は36です
# 0.016808976152955568
# 迷路を解くのにかかったステップ数は39です
# 0.027193812471354217
# 迷路を解くのにかかったステップ数は11です
# 0.025470486449242824
# 迷路を解くのにかかったステップ数は21です
# 0.029732714150114192
# 迷路を解くのにかかったステップ数は6です
# 0.021583122368898117
# 迷路を解くのにかかったステップ数は32です
# 0.03632011734699958
# 迷路を解くのにかかったステップ数は7です
# 0.015666183761809255
# 迷路を解くのにかかったステップ数は25です
# 0.028757108179585933
# 迷路を解くのにかかったステップ数は16です
# 0.026293603605878374
# 迷路を解くのにかかったステップ数は16です
# 0.023663740169529435
# 迷路を解くのにかかったステップ数は16です
# 0.03291625371659446
# 迷路を解くのにかかったステップ数は10です
# 0.0151582720763479
# 迷路を解くのにかかったステップ数は34です
# 0.023223307626224793
# 迷路を解くのにかかったステップ数は23です
# 0.016538517766697902
# 迷路を解くのにかかったステップ数は28です
# 0.018990763717438686
# 迷路を解くのにかかったステップ数は15です
# 0.02855570005450589
# 迷路を解くのにかかったステップ数は6です
# 0.031273886296053155
# 迷路を解くのにかかったステップ数は9です
# 0.020144888355050128
# 迷路を解くのにかかったステップ数は26です
# 0.02971952383652468
# 迷路を解くのにかかったステップ数は12です
# 0.033325909010491234
# 迷路を解くのにかかったステップ数は10です
# 0.024838403029565248
# 迷路を解くのにかかったステップ数は9です
# 0.036014140676799894
# 迷路を解くのにかかったステップ数は4です
# 0.01802842238351174
# 迷路を解くのにかかったステップ数は26です
# 0.03577179886536552
# 迷路を解くのにかかったステップ数は4です
# 0.026166247445486235
# 迷路を解くのにかかったステップ数は17です
# 0.02638432129397697
# 迷路を解くのにかかったステップ数は12です
# 0.02682562092466989
# 迷路を解くのにかかったステップ数は12です
# 0.02635338301977641
# 迷路を解くのにかかったステップ数は10です
# 0.034061118420774944
# 迷路を解くのにかかったステップ数は5です
# 0.012518236924113302
# 迷路を解くのにかかったステップ数は48です
# 0.023142646488897772
# 迷路を解くのにかかったステップ数は12です
# 0.022239645303040373
# 迷路を解くのにかかったステップ数は23です
# 0.03528318478986009
# 迷路を解くのにかかったステップ数は4です
# 0.02967979898619391
# 迷路を解くのにかかったステップ数は10です
# 0.025542735251310428
# 迷路を解くのにかかったステップ数は25です
# 0.016535679484290244
# 迷路を解くのにかかったステップ数は47です
# 0.019183492259131685
# 迷路を解くのにかかったステップ数は50です
# 0.02484209491552858
# 迷路を解くのにかかったステップ数は20です
# 0.02051960337017858
# 迷路を解くのにかかったステップ数は25です
# 0.02991082296699102
# 迷路を解くのにかかったステップ数は14です
# 0.026764000434049223
# 迷路を解くのにかかったステップ数は8です
# 0.03436797876603925
# 迷路を解くのにかかったステップ数は5です
# 0.02924358422555992
# 迷路を解くのにかかったステップ数は11です
# 0.022634942993432328
# 迷路を解くのにかかったステップ数は22です
# 0.03448869775036459
# 迷路を解くのにかかったステップ数は9です
# 0.03158790019753065
# 迷路を解くのにかかったステップ数は7です
# 0.024368280966528932
# 迷路を解くのにかかったステップ数は13です
# 0.014058600412742137
# 迷路を解くのにかかったステップ数は41です
# 0.02507187418314183
# 迷路を解くのにかかったステップ数は31です
# 0.03591823769703323
# 迷路を解くのにかかったステップ数は8です
# 0.03160002725511879
# 迷路を解くのにかかったステップ数は9です
# 0.025624299107183418
# 迷路を解くのにかかったステップ数は11です
# 0.023077956823373547
# 迷路を解くのにかかったステップ数は42です
# 0.025160197912568905
# 迷路を解くのにかかったステップ数は14です
# 0.025568718244245392
# 迷路を解くのにかかったステップ数は16です
# 0.03466731069045871
# 迷路を解くのにかかったステップ数は4です
# 0.024488947385187004
# 迷路を解くのにかかったステップ数は15です
# 0.02982679240452403
# 迷路を解くのにかかったステップ数は8です
# 0.03429864077230545
# 迷路を解くのにかかったステップ数は4です
# 0.03640826509076808
# 迷路を解くのにかかったステップ数は10です
# 0.022127492186295686
# 迷路を解くのにかかったステップ数は28です
# 0.023364785325314663
# 迷路を解くのにかかったステップ数は25です
# 0.02845542682409964
# 迷路を解くのにかかったステップ数は8です
# 0.022297893393577795
# 迷路を解くのにかかったステップ数は9です
# 0.029475085645056145
# 迷路を解くのにかかったステップ数は9です
# 0.03212380078490379
# 迷路を解くのにかかったステップ数は13です
# 0.020379583436228782
# 迷路を解くのにかかったステップ数は25です
# 0.024327077618728543
# 迷路を解くのにかかったステップ数は18です
# 0.02037441561845836
# 迷路を解くのにかかったステップ数は21です
# 0.028439178676882712
# 迷路を解くのにかかったステップ数は7です
# 0.0288999291956602
# 迷路を解くのにかかったステップ数は12です
# 0.032775517768585144
# 迷路を解くのにかかったステップ数は8です
# 0.022892380309469065
# 迷路を解くのにかかったステップ数は34です
# 0.02948589090881415
# 迷路を解くのにかかったステップ数は8です
# 0.015375972997705128
# 迷路を解くのにかかったステップ数は45です
# 0.021523679192150647
# 迷路を解くのにかかったステップ数は28です
# 0.033648461928118295
# 迷路を解くのにかかったステップ数は5です
# 0.026083720214103392
# 迷路を解くのにかかったステップ数は12です
# 0.024026008262841042
# 迷路を解くのにかかったステップ数は22です
# 0.03331920627485732
# 迷路を解くのにかかったステップ数は9です
# 0.028447826788534303
# 迷路を解くのにかかったステップ数は8です
# 0.03360601795223293
# 迷路を解くのにかかったステップ数は5です
# 0.020493294258418476
# 迷路を解くのにかかったステップ数は31です
# 0.02507132502743324
# 迷路を解くのにかかったステップ数は28です
# 0.03680246807309574
# 迷路を解くのにかかったステップ数は5です
# 0.034588517065547206
# 迷路を解くのにかかったステップ数は6です
# 0.033157669296528997
# 迷路を解くのにかかったステップ数は9です
# 0.02051971013771174
# 迷路を解くのにかかったステップ数は30です
# 0.01958286117642244
# 迷路を解くのにかかったステップ数は32です
# 0.03145713518707319
# 迷路を解くのにかかったステップ数は7です
# 0.025050998222770196
# 迷路を解くのにかかったステップ数は12です
# 0.026444273015236094
# 迷路を解くのにかかったステップ数は6です
# 0.02692487776235894
# 迷路を解くのにかかったステップ数は6です
# 0.020792369713911935
# 迷路を解くのにかかったステップ数は33です
# 0.026477330585019804
# 迷路を解くのにかかったステップ数は13です
# 0.03713939257892657
# 迷路を解くのにかかったステップ数は5です
# 0.016118354937361648
# 迷路を解くのにかかったステップ数は36です
# 0.02642985084028096
# 迷路を解くのにかかったステップ数は14です
# 0.02368442500150325
# 迷路を解くのにかかったステップ数は11です
# 0.024419897865569043
# 迷路を解くのにかかったステップ数は8です
# 0.025701833267520027
# 迷路を解くのにかかったステップ数は21です
# 0.02165856375457413
# 迷路を解くのにかかったステップ数は8です
# 0.03004757272051417
# 迷路を解くのにかかったステップ数は8です
# 0.03640427271216057
# 迷路を解くのにかかったステップ数は5です
# 0.03141255345666563
# 迷路を解くのにかかったステップ数は9です
# 0.027566826359317245
# 迷路を解くのにかかったステップ数は8です
# 0.018357191990003463
# 迷路を解くのにかかったステップ数は37です
# 0.02664582654422404
# 迷路を解くのにかかったステップ数は17です
# 0.025999745121493778
# 迷路を解くのにかかったステップ数は15です
# 0.03262827797278653
# 迷路を解くのにかかったステップ数は4です
# 0.01953911780466802
# 迷路を解くのにかかったステップ数は39です
# 0.027757952725520812
# 迷路を解くのにかかったステップ数は27です
# 0.020944277715125456
# 迷路を解くのにかかったステップ数は32です
# 0.03146513994252517
# 迷路を解くのにかかったステップ数は11です
# 0.03009663865146761
# 迷路を解くのにかかったステップ数は13です
# 0.027542129067287813
# 迷路を解くのにかかったステップ数は14です
# 0.028643554175843203
# 迷路を解くのにかかったステップ数は9です
# 0.025688194412184354
# 迷路を解くのにかかったステップ数は15です
# 0.02578156437959994
# 迷路を解くのにかかったステップ数は11です
# 0.021442170611476283
# 迷路を解くのにかかったステップ数は14です
# 0.032759700397079816
# 迷路を解くのにかかったステップ数は7です
# 0.024094570323047113
# 迷路を解くのにかかったステップ数は23です
# 0.02687891806910088
# 迷路を解くのにかかったステップ数は16です
# 0.02379531810112634
# 迷路を解くのにかかったステップ数は14です
# 0.024154679704395443
# 迷路を解くのにかかったステップ数は30です
# 0.027108547759912047
# 迷路を解くのにかかったステップ数は9です
# 0.03452661997833431
# 迷路を解くのにかかったステップ数は11です
# 0.01740421973600753
# 迷路を解くのにかかったステップ数は83です
# 0.025528714024656604
# 迷路を解くのにかかったステップ数は19です
# 0.032239069328685865
# 迷路を解くのにかかったステップ数は5です
# 0.013639997463206627
# 迷路を解くのにかかったステップ数は52です
# 0.01858666649116822
# 迷路を解くのにかかったステップ数は17です
# 0.03581156968217654
# 迷路を解くのにかかったステップ数は11です
# 0.03456817170716543
# 迷路を解くのにかかったステップ数は5です
# 0.0204076215781981
# 迷路を解くのにかかったステップ数は16です
# 0.02623436506170465
# 迷路を解くのにかかったステップ数は27です
# 0.024523560458565796
# 迷路を解くのにかかったステップ数は21です
# 0.031382038534541204
# 迷路を解くのにかかったステップ数は10です
# 0.03238578313478395
# 迷路を解くのにかかったステップ数は12です
# 0.028376738927204687
# 迷路を解くのにかかったステップ数は24です
# 0.027034044263078677
# 迷路を解くのにかかったステップ数は25です
# 0.026378457251733073
# 迷路を解くのにかかったステップ数は11です
# 0.022209678925050838
# 迷路を解くのにかかったステップ数は17です
# 0.0350942007990913
# 迷路を解くのにかかったステップ数は5です
# 0.026095862414190152
# 迷路を解くのにかかったステップ数は17です
# 0.029161476841080863
# 迷路を解くのにかかったステップ数は25です
# 0.02657289864357397
# 迷路を解くのにかかったステップ数は17です
# 0.036183528097256085
# 迷路を解くのにかかったステップ数は5です
# 0.031124726163360608
# 迷路を解くのにかかったステップ数は8です
# 0.03022251065946338
# 迷路を解くのにかかったステップ数は9です
# 0.019479714896523836
# 迷路を解くのにかかったステップ数は42です
# 0.024550262097360415
# 迷路を解くのにかかったステップ数は15です
# 0.030136448746207037
# 迷路を解くのにかかったステップ数は10です
# 0.021731350875927452
# 迷路を解くのにかかったステップ数は15です
# 0.03239864426547044
# 迷路を解くのにかかったステップ数は4です
# 0.03263828408914862
# 迷路を解くのにかかったステップ数は7です
# 0.03514376614545581
# 迷路を解くのにかかったステップ数は6です
# 0.03372895632389898
# 迷路を解くのにかかったステップ数は8です
# 0.03207945843580154
# 迷路を解くのにかかったステップ数は4です
# 0.03229685886217093
# 迷路を解くのにかかったステップ数は5です
# 0.026868154804945088
# 迷路を解くのにかかったステップ数は8です
# 0.02550688530338313
# 迷路を解くのにかかったステップ数は6です
# 0.020084777201187648
# 迷路を解くのにかかったステップ数は27です
# 0.031419925901704074
# 迷路を解くのにかかったステップ数は4です
# 0.018734835398886013
# 迷路を解くのにかかったステップ数は46です
# 0.031178902343023493
# 迷路を解くのにかかったステップ数は4です
# 0.025161831540769827
# 迷路を解くのにかかったステップ数は6です
# 0.034809414942255354
# 迷路を解くのにかかったステップ数は7です
# 0.03497254618444495
# 迷路を解くのにかかったステップ数は5です
# 0.03231997448410712
# 迷路を解くのにかかったステップ数は7です
# 0.015060445625029492
# 迷路を解くのにかかったステップ数は18です
# 0.03480584339598804
# 迷路を解くのにかかったステップ数は5です
# 0.027274260762691682
# 迷路を解くのにかかったステップ数は9です
# 0.030391669684783337
# 迷路を解くのにかかったステップ数は4です
# 0.02115157923115528
# 迷路を解くのにかかったステップ数は43です
# 0.020019436986372055
# 迷路を解くのにかかったステップ数は37です
# 0.030110479523680622
# 迷路を解くのにかかったステップ数は4です
# 0.03374542605476477
# 迷路を解くのにかかったステップ数は5です
# 0.026225651858954827
# 迷路を解くのにかかったステップ数は7です
# 0.03158352217415902
# 迷路を解くのにかかったステップ数は14です
# 0.02610852030368198
# 迷路を解くのにかかったステップ数は20です
# 0.02064863846537822
# 迷路を解くのにかかったステップ数は21です
# 0.017034936530713862
# 迷路を解くのにかかったステップ数は55です
# 0.026571925868642515
# 迷路を解くのにかかったステップ数は25です
# 0.017575057081106474
# 迷路を解くのにかかったステップ数は29です
# 0.03436563161369331
# 迷路を解くのにかかったステップ数は5です
# 0.024441938569894336
# 迷路を解くのにかかったステップ数は17です
# 0.029772496797827064
# 迷路を解くのにかかったステップ数は4です
# 0.01649309130179749
# 迷路を解くのにかかったステップ数は36です
# 0.01969941893740139
# 迷路を解くのにかかったステップ数は8です
# 0.026492981574523622
# 迷路を解くのにかかったステップ数は25です
# 0.022691907264124747
# 迷路を解くのにかかったステップ数は26です
# 0.029303338158645914
# 迷路を解くのにかかったステップ数は9です
# 0.031314518816850975
# 迷路を解くのにかかったステップ数は5です
# 0.033437320833692
# 迷路を解くのにかかったステップ数は5です
# 0.02358549660048545
# 迷路を解くのにかかったステップ数は20です
# 0.02640704960400289
# 迷路を解くのにかかったステップ数は17です
# 0.033783620914279486
# 迷路を解くのにかかったステップ数は8です
# 0.03390538371657942
# 迷路を解くのにかかったステップ数は5です
# 0.030842495904243872
# 迷路を解くのにかかったステップ数は21です
# 0.01842337500734499
# 迷路を解くのにかかったステップ数は42です
# 0.033792263098361114
# 迷路を解くのにかかったステップ数は5です
# 0.029195985419886106
# 迷路を解くのにかかったステップ数は4です
# 0.022651283471463377
# 迷路を解くのにかかったステップ数は11です
# 0.02711916230331317
# 迷路を解くのにかかったステップ数は12です
# 0.032464059140112966
# 迷路を解くのにかかったステップ数は13です
# 0.02902025753283108
# 迷路を解くのにかかったステップ数は17です
# 0.036305657182873374
# 迷路を解くのにかかったステップ数は5です
# 0.029022101409351922
# 迷路を解くのにかかったステップ数は4です
# 0.018512844925479235
# 迷路を解くのにかかったステップ数は21です
# 0.03060199554550949
# 迷路を解くのにかかったステップ数は14です
# 0.033409598560880785
# 迷路を解くのにかかったステップ数は9です
# 0.02711513199619342
# 迷路を解くのにかかったステップ数は23です
# 0.026904378859847422
# 迷路を解くのにかかったステップ数は9です
# 0.021187787782887352
# 迷路を解くのにかかったステップ数は8です
# 0.017806724857405518
# 迷路を解くのにかかったステップ数は14です
# 0.01659276890075624
# 迷路を解くのにかかったステップ数は33です
# 0.022213078161037708
# 迷路を解くのにかかったステップ数は19です
# 0.0189851812653265
# 迷路を解くのにかかったステップ数は17です
# 0.03349970229661403
# 迷路を解くのにかかったステップ数は5です
# 0.019908116625349304
# 迷路を解くのにかかったステップ数は28です
# 0.028802300602437478
# 迷路を解くのにかかったステップ数は4です
# 0.03060079402453278
# 迷路を解くのにかかったステップ数は16です
# 0.029061771164421935
# 迷路を解くのにかかったステップ数は7です
# 0.02864120318995657
# 迷路を解くのにかかったステップ数は4です
# 0.019584711892573825
# 迷路を解くのにかかったステップ数は33です
# 0.028207056583409454
# 迷路を解くのにかかったステップ数は7です
# 0.025009189699304463
# 迷路を解くのにかかったステップ数は21です
# 0.026955105709721955
# 迷路を解くのにかかったステップ数は17です
# 0.033313766028447905
# 迷路を解くのにかかったステップ数は7です
# 0.028004740259558597
# 迷路を解くのにかかったステップ数は17です
# 0.03162574124273056
# 迷路を解くのにかかったステップ数は12です
# 0.01912132324346158
# 迷路を解くのにかかったステップ数は16です
# 0.026860730666193378
# 迷路を解くのにかかったステップ数は8です
# 0.028562313328983235
# 迷路を解くのにかかったステップ数は4です
# 0.028270554838000644
# 迷路を解くのにかかったステップ数は4です
# 0.024486923035007976
# 迷路を解くのにかかったステップ数は23です
# 0.019757330040873683
# 迷路を解くのにかかったステップ数は47です
# 0.01670876527421568
# 迷路を解くのにかかったステップ数は62です
# 0.03161728878221058
# 迷路を解くのにかかったステップ数は8です
# 0.02212685201515903
# 迷路を解くのにかかったステップ数は12です
# 0.029564756497395053
# 迷路を解くのにかかったステップ数は9です
# 0.026011969137706245
# 迷路を解くのにかかったステップ数は14です
# 0.028403302937272237
# 迷路を解くのにかかったステップ数は9です
# 0.027769549556036707
# 迷路を解くのにかかったステップ数は13です
# 0.03233577632357276
# 迷路を解くのにかかったステップ数は8です
# 0.022497704559971146
# 迷路を解くのにかかったステップ数は12です
# 0.028348927902611926
# 迷路を解くのにかかったステップ数は4です
# 0.03321720791042418
# 迷路を解くのにかかったステップ数は5です
# 0.02453662412945759
# 迷路を解くのにかかったステップ数は6です
# 0.021928448819005866
# 迷路を解くのにかかったステップ数は29です
# 0.03242338307150601
# 迷路を解くのにかかったステップ数は5です
# 0.021177210887162873
# 迷路を解くのにかかったステップ数は11です
# 0.026169660965548333
# 迷路を解くのにかかったステップ数は14です
# 0.0278502545138663
# 迷路を解くのにかかったステップ数は4です
# 0.024810093150378867
# 迷路を解くのにかかったステップ数は16です
# 0.027508494812770762
# 迷路を解くのにかかったステップ数は4です
# 0.02099680036485818
# 迷路を解くのにかかったステップ数は6です
# 0.02024326800513948
# 迷路を解くのにかかったステップ数は18です
# 0.026114347237917945
# 迷路を解くのにかかったステップ数は12です
# 0.024630910460439262
# 迷路を解くのにかかったステップ数は6です
# 0.017831697878912547
# 迷路を解くのにかかったステップ数は25です
# 0.025495053944045387
# 迷路を解くのにかかったステップ数は15です
# 0.028557532149808787
# 迷路を解くのにかかったステップ数は7です
# 0.03423904173064925
# 迷路を解くのにかかったステップ数は5です
# 0.022328018776646127
# 迷路を解くのにかかったステップ数は15です
# 0.016258806783436205
# 迷路を解くのにかかったステップ数は31です
# 0.020613614482202766
# 迷路を解くのにかかったステップ数は13です
# 0.02756524272732437
# 迷路を解くのにかかったステップ数は15です
# 0.024601503478014625
# 迷路を解くのにかかったステップ数は18です
# 0.02079009719760677
# 迷路を解くのにかかったステップ数は6です
# 0.023844657873398983
# 迷路を解くのにかかったステップ数は14です
# 0.026683999502153055
# 迷路を解くのにかかったステップ数は4です
# 0.020235878660360668
# 迷路を解くのにかかったステップ数は10です
# 0.023407524453917833
# 迷路を解くのにかかったステップ数は9です
# 0.026352190924438565
# 迷路を解くのにかかったステップ数は4です
# 0.02044175264179704
# 迷路を解くのにかかったステップ数は19です
# 0.01989055459872069
# 迷路を解くのにかかったステップ数は8です
# 0.024505168697021643
# 迷路を解くのにかかったステップ数は6です
# 0.029599455216509946
# 迷路を解くのにかかったステップ数は10です
# 0.03175106758718885
# 迷路を解くのにかかったステップ数は5です
# 0.025850134663867458
# 迷路を解くのにかかったステップ数は22です
# 0.03404704261076899
# 迷路を解くのにかかったステップ数は6です
# 0.03169104713597175
# 迷路を解くのにかかったステップ数は5です
# 0.025470700176875347
# ...
# 0.005902969065346
# 迷路を解くのにかかったステップ数は5です
# 0.00011899445938823739
# 迷路を解くのにかかったステップ数は4です
# 0.00011881580235848475
# 迷路を解くのにかかったステップ数は4です
# 0.0001186375646809153
# 迷路を解くのにかかったステップ数は4です
# 0.00011845974499813481
# 迷路を解くのにかかったステップ数は4です
# 0.0001182823419575759
# 迷路を解くのにかかったステップ数は4です
# 0.00011810535421519306
# 迷路を解くのにかかったステップ数は4です
# 0.00011792878042880556
# 迷路を解くのにかかったステップ数は4です
# 0.0001177526192652524
# 迷路を解くのにかかったステップ数は4です
# 0.00011757686939545871
# 迷路を解くのにかかったステップ数は4です
# 0.00011740152949444964
# 迷路を解くのにかかったステップ数は4です
# 0.00011722659824544863
# 迷路を解くのにかかったステップ数は4です
# 0.00011705207433493868
# 迷路を解くのにかかったステップ数は4です
# 0.0001168779564558126
# 迷路を解くのにかかったステップ数は4です
# 0.00011670424330557667
# 迷路を解くのにかかったステップ数は4です
# 0.0001165309335885269
# 迷路を解くのにかかったステップ数は4です
# 0.005203962082705531
# 迷路を解くのにかかったステップ数は7です
# 0.007548000560670519
# 迷路を解くのにかかったステップ数は5です
# 0.00011850013330651915
# 迷路を解くのにかかったステップ数は4です
# 0.0001183234005308776
# 迷路を解くのにかかったステップ数は4です
# 0.00011814707847509435
# 迷路を解くのにかかったステップ数は4です
# 0.011224186847726032
# 迷路を解くのにかかったステップ数は7です
# 0.00011984637301322171
# 迷路を解くのにかかったステップ数は4です
# 0.00011966713303196604
# 迷路を解くのにかかったステップ数は4です
# 0.00011948830987725152
# 迷路を解くのにかかったステップ数は4です
# 0.00011930990221836139
# 迷路を解くのにかかったステップ数は4です
# 0.00011913190873099038
# 迷路を解くのにかかったステップ数は4です
# 0.00011895432809640085
# 迷路を解くのにかかったステップ数は4です
# 0.00011877715899854743
# 迷路を解くのにかかったステップ数は4です
# 0.00011860040013177142
# 迷路を解くのにかかったステップ数は4です
# 0.00011842405019001773
# 迷路を解くのにかかったステップ数は4です
# 0.00011824810787694831
# 迷路を解くのにかかったステップ数は4です
# 0.00011807257189897728
# 迷路を解くのにかかったステップ数は4です
# 0.0007696397753262779
# 迷路を解くのにかかったステップ数は6です
# 0.00011853192574706566
# 迷路を解くのにかかったステップ数は4です
# 0.00011835625032493614
# 迷路を解くのにかかったステップ数は4です
# 0.00011818097915972971
# 迷路を解くのにかかったステップ数は4です
# 0.00011800611097670735
# 迷路を解くのにかかったステップ数は4です
# 0.00011783164450333275
# 迷路を解くのにかかったステップ数は4です
# 0.00011765757847629352
# 迷路を解くのにかかったステップ数は4です
# 0.00011748391163443487
# 迷路を解くのにかかったステップ数は4です
# 0.00011731064272278496
# 迷路を解くのにかかったステップ数は4です
# 0.0007621366646603069
# 迷路を解くのにかかったステップ数は6です
# 0.00011771696894988422
# 迷路を解くのにかかったステップ数は4です
# 0.00011754368361727163
# 迷路を解くのにかかったステップ数は4です
# 0.00011737079383639451
# 迷路を解くのにかかったステップ数は4です
# 0.000117198298368708
# 迷路を解くのにかかったステップ数は4です
# 0.0001170261959824205
# 迷路を解くのにかかったステップ数は4です
# 0.00011685448544900695
# 迷路を解くのにかかったステップ数は4です
# 0.00011668316554782569
# 迷路を解くのにかかったステップ数は4です
# 0.00011651223505954912
# 迷路を解くのにかかったステップ数は4です
# 0.00011634169277213984
# 迷路を解くのにかかったステップ数は4です
# 0.00011617153747701166
# 迷路を解くのにかかったステップ数は4です
# 0.00011600176797122146
# 迷路を解くのにかかったステップ数は4です
# 0.00011583238305593654
# 迷路を解くのにかかったステップ数は4です
# 0.0001156633815384148
# 迷路を解くのにかかったステップ数は4です
# 0.00011549476222875912
# 迷路を解くのにかかったステップ数は4です
# 0.00011532652394271366
# 迷路を解くのにかかったステップ数は4です
# 0.00011515866550131267
# 迷路を解くのにかかったステップ数は4です
# 0.0001149911857286981
# 迷路を解くのにかかったステップ数は4です
# 0.00011482408345549113
# 迷路を解くのにかかったステップ数は4です
# 0.0007723251332765017
# 迷路を解くのにかかったステップ数は6です
# 0.00011530636911488614
# 迷路を解くのにかかったステップ数は4です
# 0.00011513903100237623
# 迷路を解くのにかかったステップ数は4です
# 0.00011497206880907874
# 迷路を解くのにかかったステップ数は4です
# 0.0001148054813793764
# 迷路を解くのにかかったステップ数は4です
# 0.00011463926756078487
# 迷路を解くのにかかったステップ数は4です
# 0.00011447342620671437
# 迷路を解くのにかかったステップ数は4です
# 0.00011430795617467081
# 迷路を解くのにかかったステップ数は4です
# 0.00011414285632689331
# 迷路を解くのにかかったステップ数は4です
# 0.0001139781255284876
# 迷路を解くのにかかったステップ数は4です
# 0.00011381376265164967
# 迷路を解くのにかかったステップ数は4です
# 0.007925818413610923
# 迷路を解くのにかかったステップ数は8です
# 0.00011410716310812467
# 迷路を解くのにかかったステップ数は4です
# 0.00011394286817843248
# 迷路を解くのにかかったステップ数は4です
# 0.00011377893901828688
# 迷路を解くのにかかったステップ数は4です
# 0.0001136153745129832
# 迷路を解くのにかかったステップ数は4です
# 0.00011345217355385531
# 迷路を解くのにかかったステップ数は4です
# 0.00011328933503491727
# 迷路を解くのにかかったステップ数は4です
# 0.00011312685785455287
# 迷路を解くのにかかったステップ数は4です
# 0.00011296474091617922
# 迷路を解くのにかかったステップ数は4です
# 0.00011280298312667247
# 迷路を解くのにかかったステップ数は4です
# 0.00011264158339832023
# 迷路を解くのにかかったステップ数は4です
# 0.00011248054064643808
# 迷路を解くのにかかったステップ数は4です
# 0.0001123198537908562
# 迷路を解くのにかかったステップ数は4です
# 0.0001121595217556436
# 迷路を解くのにかかったステップ数は4です
# 0.00011199954346954779
# 迷路を解くのにかかったステップ数は4です
# 0.00011183991786450388
# 迷路を解くのにかかったステップ数は4です
# 0.0001116806438768627
# 迷路を解くのにかかったステップ数は4です
# 0.00011152172044758078
# 迷路を解くのにかかったステップ数は4です
# 0.0001113631465212428
# 迷路を解くのにかかったステップ数は4です
# 0.00011120492104642679
# 迷路を解くのにかかったステップ数は4です
# 0.00011104704297560958
# 迷路を解くのにかかったステップ数は4です
# 0.0001108895112663065
# 迷路を解くのにかかったステップ数は4です
# 0.00011073232487836347
# 迷路を解くのにかかったステップ数は4です
# 0.00011057548277720701
# 迷路を解くのにかかったステップ数は4です
# 0.0001104189839309759
# 迷路を解くのにかかったステップ数は4です
# 0.00011026282731260804
# 迷路を解くのにかかったステップ数は4です
# 0.00011010701189892967
# 迷路を解くのにかかったステップ数は4です
# 0.00010995153666980024
# 迷路を解くのにかかったステップ数は4です
# 0.00010979640060970654
# 迷路を解くのにかかったステップ数は4です
# 0.00010964160270726404
# 迷路を解くのにかかったステップ数は4です
# 0.00010948714195434164
# 迷路を解くのにかかったステップ数は4です
# 0.014770219207069803
# 迷路を解くのにかかったステップ数は5です
# 0.00011078160376933564
# 迷路を解くのにかかったステップ数は4です
# 0.00011062477364975898
# 迷路を解くのにかかったステップ数は4です
# 0.00011046828614970101
# 迷路を解くのにかかったステップ数は4です
# 0.00011031214024590213
# 迷路を解くのにかかったステップ数は4です
# 0.00011015633492093314
# 迷路を解くのにかかったステップ数は4です
# 0.00011000086916073543
# 迷路を解くのにかかったステップ数は4です
# 0.00010984574195365814
# 迷路を解くのにかかったステップ数は4です
# 0.00010969095229443337
# 迷路を解くのにかかったステップ数は4です
# 0.00010953649917944727
# 迷路を解くのにかかったステップ数は4です
# 0.00010938238160996747
# 迷路を解くのにかかったステップ数は4です
# 0.00010922859859027138
# 迷路を解くのにかかったステップ数は4です
# 0.00010907514912971827
# 迷路を解くのにかかったステップ数は4です
# 0.00010892203223936397
# 迷路を解くのにかかったステップ数は4です
# 0.0001087692469361602
# 迷路を解くのにかかったステップ数は4です
# 0.00010861679223979782
# 迷路を解くのにかかったステップ数は4です
# 0.00010846466717301471
# 迷路を解くのにかかったステップ数は4です
# 0.0010731172824223886
# 迷路を解くのにかかったステップ数は6です
# 0.00010993341954084303
# 迷路を解くのにかかったステップ数は4です
# 0.00010977787529007493
# 迷路を解くのにかかったステップ数は4です
# 0.00010962267133039381
# 迷路を解くのにかかったステップ数は4です
# 0.00010946780664417488
# 迷路を解くのにかかったステップ数は4です
# 0.00010931328021629569
# 迷路を解くのにかかったステップ数は4です
# 0.00010915909103736401
# 迷路を解くのにかかったステップ数は4です
# 0.00010900523809945564
# 迷路を解くのにかかったステップ数は4です
# 0.00010885172040146383
# 迷路を解くのにかかったステップ数は4です
# 0.00010869853694332483
# 迷路を解くのにかかったステップ数は4です
# 0.0001085456867301964
# 迷路を解くのにかかったステップ数は4です
# 0.0001083931687711594
# 迷路を解くのにかかったステップ数は4です
# 0.00010824098207755763
# 迷路を解くのにかかったステップ数は4です
# 0.00010808912566662079
# 迷路を解くのにかかったステップ数は4です
# 0.00010793759855856839
# 迷路を解くのにかかったステップ数は4です
# 0.00010778639977516513
# 迷路を解くのにかかったステップ数は4です
# 0.00010763552834573741
# 迷路を解くのにかかったステップ数は4です
# 0.0001074849832999247
# 迷路を解くのにかかったステップ数は4です
# 0.00010733476367339942
# 迷路を解くのにかかったステップ数は4です
# 0.00010718486850255348
# 迷路を解くのにかかったステップ数は4です
# 0.00010703529683173162
# 迷路を解くのにかかったステップ数は4です
# 0.00010688604770484316
# 迷路を解くのにかかったステップ数は4です
# 0.00010673712017108617
# 迷路を解くのにかかったステップ数は4です
# 0.00010658851328335323
# 迷路を解くのにかかったステップ数は4です
# 0.00010644022609863132
# 迷路を解くのにかかったステップ数は4です
# 0.00010629225767446512
# 迷路を解くのにかかったステップ数は4です
# 0.00010614460707721735
# 迷路を解くのにかかったステップ数は4です
# 0.00010599727337068767
# 迷路を解くのにかかったステップ数は4です
# 0.00010585025562729515
# 迷路を解くのにかかったステップ数は4です
# 0.00010570355291924637
# 迷路を解くのにかかったステップ数は4です
# 0.00010555716432513644
# 迷路を解くのにかかったステップ数は4です
# 0.00010541108892470974
# 迷路を解くのにかかったステップ数は4です
# 0.00010526532580219664
# 迷路を解くのにかかったステップ数は4です
# 0.00010511987404591408
# 迷路を解くのにかかったステップ数は4です
# 0.00010497473274492493
# 迷路を解くのにかかったステップ数は4です
# 0.00010482990099581297
# 迷路を解くのにかかったステップ数は4です
# 0.00010468537789445724
# 迷路を解くのにかかったステップ数は4です
# 0.007679873525855902
# 迷路を解くのにかかったステップ数は7です
# 0.00010590942459305988
# 迷路を解くのにかかったステップ数は4です
# 0.005758352678311882
# 迷路を解くのにかかったステップ数は5です
# 0.00010817446464798973
# 迷路を解くのにかかったステップ数は4です
# 0.00010802127111104705
# 迷路を解くのにかかったステップ数は4です
# 0.000107868414787752
# 迷路を解くのにかかったステップ数は4です
# 0.00010771589465872599
# 迷路を解くのにかかったステップ数は4です
# 0.00010756370970925857
# 迷路を解くのにかかったステップ数は4です
# 0.0001074118589269057
# 迷路を解くのにかかったステップ数は4です
# 0.000107260341303839
# 迷路を解くのにかかったステップ数は4です
# 0.00010710915583872233
# 迷路を解くのにかかったステップ数は4です
# 0.00010695830152873502
# 迷路を解くのにかかったステップ数は4です
# 0.0001068077773797426
# 迷路を解くのにかかったステップ数は4です
# 0.00010665758239904958
# 迷路を解くのにかかったステップ数は4です
# 0.00010650771559848633
# 迷路を解くのにかかったステップ数は4です
# 0.00010635817599302568
# 迷路を解くのにかかったステップ数は4です
# 0.00010620896260271498
# 迷路を解くのにかかったステップ数は4です
# 0.00010606007445053238
# 迷路を解くのにかかったステップ数は4です
# 0.00010591151056226714
# 迷路を解くのにかかったステップ数は4です
# 0.00010576326996938543
# 迷路を解くのにかかったステップ数は4です
# 0.00010561535170533877
# 迷路を解くのにかかったステップ数は4です
# 0.00010546775480902966
# 迷路を解くのにかかったステップ数は4です
# 0.00010532047832042266
# 迷路を解くのにかかったステップ数は4です
# 0.00010517352128596412
# 迷路を解くのにかかったステップ数は4です
# 0.00010502688275442233
# 迷路を解くのにかかったステップ数は4です
# 0.00010488056177779606
# 迷路を解くのにかかったステップ数は4です
# 0.00010473455741157782
# 迷路を解くのにかかったステップ数は4です
# 0.00010458886871713867
# 迷路を解くのにかかったステップ数は4です
# 0.00010444349475634837
# 迷路を解くのにかかったステップ数は4です
# 0.00010429843459577263
# 迷路を解くのにかかったステップ数は4です
# 0.00010415368730665913
# 迷路を解くのにかかったステップ数は4です
# 0.00010400925196281472
# 迷路を解くのにかかったステップ数は4です
# 0.00010386512764020252
# 迷路を解くのにかかったステップ数は4です
# 0.007414699146113802
# 迷路を解くのにかかったステップ数は5です
# 0.00010521931354463398
# 迷路を解くのにかかったステップ数は4です
# 0.0001050727077894823
# 迷路を解くのにかかったステップ数は4です
# 0.00010492641878176142
# 迷路を解くのにかかったステップ数は4です
# 0.00010478044558337452
# 迷路を解くのにかかったステップ数は4です
# 0.00010463478726021897
# 迷路を解くのにかかったステップ数は4です
# 0.00010448944288288416
# 迷路を解くのにかかったステップ数は4です
# 0.00010434441152299247
# 迷路を解くのにかかったステップ数は4です
# 0.00010419969225761508
# 迷路を解くのにかかったステップ数は4です
# 0.00010405528416745609
# 迷路を解くのにかかったステップ数は4です
# 0.00010391118633488843
# 迷路を解くのにかかったステップ数は4です
# 0.00010376739784827499
# 迷路を解くのにかかったステップ数は4です
# 0.00010362391779649349
# 迷路を解くのにかかったステップ数は4です
# 0.00010348074527468352
# 迷路を解くのにかかったステップ数は4です
# 0.00010333787937894402
# 迷路を解くのにかかったステップ数は4です
# 0.00010319531920987939
# 迷路を解くのにかかったステップ数は4です
# 0.00010305306387260738
# 迷路を解くのにかかったステップ数は4です
# 0.00010291111247277872
# 迷路を解くのにかかったステップ数は4です
# 0.00010276946412216643
# 迷路を解くのにかかったステップ数は4です
# 0.00010262811793443306
# 迷路を解くのにかかったステップ数は4です
# 0.00010248707302679561
# 迷路を解くのにかかったステップ数は4です
# 0.00010234632851981998
# 迷路を解くのにかかったステップ数は4です
# 0.00010220588353634713
# 迷路を解くのにかかったステップ数は4です
# 0.00010206573720535376
# 迷路を解くのにかかったステップ数は4です
# 0.00010192588865550953
# 迷路を解くのにかかったステップ数は4です
# 0.00010178633702128846
# 迷路を解くのにかかったステップ数は4です
# 0.007684469572713322
# 迷路を解くのにかかったステップ数は7です
# 0.01624077123698657
# 迷路を解くのにかかったステップ数は14です
# 0.0001038111467739633
# 迷路を解くのにかかったステップ数は4です
# 0.0001036667612887769
# 迷路を解くのにかかったステップ数は4です
# 0.00010352268809534762
# 迷路を解くのにかかったステップ数は4です
# 0.00010337892626373357
# 迷路を解くのにかかったステップ数は4です
# 0.00010323547487161916
# 迷路を解くのにかかったステップ数は4です
# 0.007503596428886117
# 迷路を解くのにかかったステップ数は6です
# 0.00010433638346587365
# 迷路を解くのにかかったステップ数は4です
# 0.00010419095750060017
# 迷路を解くのにかかったステップ数は4です
# 0.00010404584635493024
# 迷路を解くのにかかったステップ数は4です
# 0.00010390104909490869
# 迷路を解くのにかかったステップ数は4です
# 0.00010375656478973927
# 迷路を解くのにかかったステップ数は4です
# 0.00010361239251198287
# 迷路を解くのにかかったステップ数は4です
# 0.00010346853133782943
# 迷路を解くのにかかったステップ数は4です
# 0.00010332498034720024
# 迷路を解くのにかかったステップ数は4です
# 0.00010318173862356242
# 迷路を解くのにかかったステップ数は4です
# 0.00010303880525423326
# 迷路を解くのにかかったステップ数は4です
# 0.00010289617932784934
# 迷路を解くのにかかったステップ数は4です
# 0.00010275385993898907
# 迷路を解くのにかかったステップ数は4です
# 0.00010261184618448604
# 迷路を解くのにかかったステップ数は4です
# 0.00010247013716512942
# 迷路を解くのにかかったステップ数は4です
# 0.01545545588577333
# 迷路を解くのにかかったステップ数は17です
# 0.00010273481179210982
# 迷路を解くのにかかったステップ数は4です
# 0.00010259287072195882
# 迷路を解くのにかかったステップ数は4です
# 0.0001024512340062401
# 迷路を解くのにかかったステップ数は4です
# 0.00010230990075078784
# 迷路を解くのにかかったステップ数は4です
# 0.00010216887006628175
# 迷路を解くのにかかったステップ数は4です
# 0.00010202814106410711
# 迷路を解くのにかかったステップ数は4です
# 0.0001018877128605186
# 迷路を解くのにかかったステップ数は4です
# 0.00010174758457520998
# 迷路を解くのにかかったステップ数は4です
# 0.017618572756518496
# 迷路を解くのにかかったステップ数は9です
# 0.00010238680526410745
# 迷路を解くのにかかったステップ数は4です
# 0.00010224565422464575
# 迷路を解くのにかかったステップ数は4です
# 0.00010210480495051293
# 迷路を解くのにかかったステップ数は4です
# 0.0001019642565562185
# 迷路を解くのにかかったステップ数は4です
# 0.00010182400816484112
# 迷路を解くのにかかったステップ数は4です
# 0.0010522768410011303
# 迷路を解くのにかかったステップ数は6です
# 0.00010325958471328871
# 迷路を解くのにかかったステップ数は4です
# 0.005754658113417219
# 迷路を解くのにかかったステップ数は5です
# 0.00010551825857310973
# 迷路を解くのにかかったステップ数は4です
# 0.00010536886486364706
# 迷路を解くのにかかったステップ数は4です
# 0.00010521980116233974
# 迷路を解くのにかかったステップ数は4です
# 0.007457302864614138
# 迷路を解くのにかかったステップ数は5です
# 0.00010667963102198915
# 迷路を解くのにかかったステップ数は4です
# 0.005833580293098606
# 迷路を解くのにかかったステップ数は6です
# 0.00010704831438350382
# 迷路を解くのにかかったステップ数は4です
# 0.00010689611773034065
# 迷路を解くのにかかったステップ数は4です
# 0.00010674425787170422
# 迷路を解くのにかかったステップ数は4です
# 0.00010659273378689884
# 迷路を解くのにかかったステップ数は4です
# 0.0001064415444570828
# 迷路を解くのにかかったステップ数は4です
# 0.011176924911223006
# 迷路を解くのにかかったステップ数は10です
# 0.0001066201676440965
# 迷路を解くのにかかったステップ数は4です
# 0.00010646920977087091
# 迷路を解くのにかかったステップ数は4です
# 0.00010631858430641943
# 迷路を解くのにかかったステップ数は4です
# 0.00010616829024773233
# 迷路を解くのにかかったステップ数は4です
# 0.00010601832659355628
# 迷路を解くのにかかったステップ数は4です
# 0.00010586869234940205
# 迷路を解くのにかかったステップ数は4です
# 0.00010571938652293323
# 迷路を解くのにかかったステップ数は4です
# 0.0001055704081253865
# 迷路を解くのにかかったステップ数は4です
# 0.00010542175617342863
# 迷路を解くのにかかったステップ数は4です
# 0.000105273429685204
# 迷路を解くのにかかったステップ数は4です
# 0.00010512542768446919
# 迷路を解くのにかかったステップ数は4です
# 0.00010497774919849146
# 迷路を解くのにかかったステップ数は4です
# 0.00010483039325689296
# 迷路を解くのにかかったステップ数は4です
# 0.00010468335889432089
# 迷路を解くのにかかったステップ数は4です
# 0.00010453664514906711
# 迷路を解くのにかかったステップ数は4です
# 0.00010439025106219468
# 迷路を解くのにかかったステップ数は4です
# 0.007386717684157322
# 迷路を解くのにかかったステップ数は5です
# 0.00010590710884033445
# 迷路を解くのにかかったステップ数は4です
# 0.00010575773346325687
# 迷路を解くのにかかったステップ数は4です
# 0.00010560868528321785
# 迷路を解くのにかかったステップ数は4です
# 0.00010545996331960553
# 迷路を解くのにかかったステップ数は4です
# 0.00010531156659542322
# 迷路を解くのにかかったステップ数は4です
# 0.00010516349413619043
# 迷路を解くのにかかったステップ数は4です
# 0.00010501574497337419
# 迷路を解くのにかかったステップ数は4です
# 0.00010486831814071097
# 迷路を解くのにかかったステップ数は4です
# 0.00010472121267465512
# 迷路を解くのにかかったステップ数は4です
# 0.00010457442761834792
# 迷路を解くのにかかったステップ数は4です
# 0.00010442796201606125
# 迷路を解くのにかかったステップ数は4です
# 0.00010428181491564225
# 迷路を解くのにかかったステップ数は4です
# 0.00010413598536984647
# 迷路を解くのにかかったステップ数は4です
# 0.00010399047243472284
# 迷路を解くのにかかったステップ数は4です
# 0.0007168169087068718
# 迷路を解くのにかかったステップ数は6です
# 0.00010436350838220927
# 迷路を解くのにかかったステップ数は4です
# 0.00010421794527170529
# 迷路を解くのにかかったステップ数は4です
# 0.00010407269703085207
# 迷路を解くのにかかったステップ数は4です
# 0.0001039277627292827
# 迷路を解くのにかかったステップ数は4です
# 0.00010378314143780817
# 迷路を解くのにかかったステップ数は4です
# 0.013933935546091302
# 迷路を解くのにかかったステップ数は7です
# 0.0001047157626548811
# 迷路を解くのにかかったステップ数は4です
# 0.00010456943597938681
# 迷路を解くのにかかったステップ数は4です
# 0.00010442342623504875
# 迷路を解くのにかかったステップ数は4です
# 0.00010427773248342662
# 迷路を解くのにかかったステップ数は4です
# 0.00010413235379027339
# 迷路を解くのにかかったステップ数は4です
# 0.005697426203481255
# 迷路を解くのにかかったステップ数は5です
# 0.00010631381783564493
# 迷路を解くのにかかったステップ数は4です
# 0.00010616319486297194
# 迷路を解くのにかかったステップ数は4です
# 0.00010601290369326296
# 迷路を解くのにかかったステップ数は4です
# 0.00010586294332460373
# 迷路を解くのにかかったステップ数は4です
# 0.00010571331276118534
# 迷路を解くのにかかったステップ数は4です
# 0.0001055640110078403
# 迷路を解くのにかかったステップ数は4です
# 0.00010541503707565871
# 迷路を解くのにかかったステップ数は4です
# 0.0001052663899798168
# 迷路を解くのにかかったステップ数は4です
# 0.00010511806873623021
# 迷路を解くのにかかったステップ数は4です
# 0.011635325564868557
# 迷路を解くのにかかったステップ数は8です
# 0.00010534963710970204
# 迷路を解くのにかかったステップ数は4です
# 0.00010520146721254087
# 迷路を解くのにかかったステップ数は4です
# 0.0001050536210336823
# 迷路を解くのにかかったステップ数は4です
# 0.0007235766260269357
# 迷路を解くのにかかったステップ数は6です
# 0.00010543393360784538
# 迷路を解くのにかかったステップ数は4です
# 0.00010528603257668571
# 迷路を解くのにかかったステップ数は4です
# 0.0001051384534818886
# 迷路を解くのにかかったステップ数は4です
# 0.00010499119536523226
# 迷路を解くのにかかったステップ数は4です
# 0.00010484425727072012
# 迷路を解くのにかかったステップ数は4です
# 0.0001046976382465003
# 迷路を解くのにかかったステップ数は4です
# 0.00010455133734456248
# 迷路を解くのにかかったステップ数は4です
# 0.00010440535362054269
# 迷路を解くのにかかったステップ数は4です
# 0.00010425968613343977
# 迷路を解くのにかかったステップ数は4です
# 0.00010411433394502548
# 迷路を解くのにかかったステップ数は4です
# 0.00010396929612324678
# 迷路を解くのにかかったステップ数は4です
# 0.00010382457173571669
# 迷路を解くのにかかったステップ数は4です
# 0.00010368015985638083
# 迷路を解くのにかかったステップ数は4です
# 0.00010353605956219761
# 迷路を解くのにかかったステップ数は4です
# 0.00010339226993324145
# 迷路を解くのにかかったステップ数は4です
# 0.00010324879005224044
# 迷路を解くのにかかったステップ数は4です
# 0.00010310561900722832
# 迷路を解くのにかかったステップ数は4です
# 0.00010296275588813925
# 迷路を解くのにかかったステップ数は4です
# 0.000102820199788405
# 迷路を解くのにかかったステップ数は4です
# 0.0001026779498060626
# 迷路を解くのにかかったステップ数は4です
# 0.00010253600504105597
# 迷路を解くのにかかったステップ数は4です
# 0.00010239436459822141
# 迷路を解くのにかかったステップ数は4です
# 0.00010225302758377257
# 迷路を解くのにかかったステップ数は4です
# 0.00010211199310944863
# 迷路を解くのにかかったステップ数は4です
# 0.00010197126028849276
# 迷路を解くのにかかったステップ数は4です
# 0.00010183082823836268
# 迷路を解くのにかかったステップ数は4です
# 0.00010169069607970059
# 迷路を解くのにかかったステップ数は4です
# 0.00010155086293688097
# 迷路を解くのにかかったステップ数は4です
# 0.00010141132793560059
# 迷路を解くのにかかったステップ数は4です
# 0.00010127209020806965
# 迷路を解くのにかかったステップ数は4です
# 0.00010113314888616316
# 迷路を解くのにかかったステップ数は4です
# 0.00010099450310798244
# 迷路を解くのにかかったステップ数は4です
# 0.0001008561520125322
# 迷路を解くのにかかったステップ数は4です
# 0.00010071809474396275
# 迷路を解くのにかかったステップ数は4です
# 0.00010058033044763612
# 迷路を解くのにかかったステップ数は4です
# 0.000100442858274027
# 迷路を解くのにかかったステップ数は4です
# 0.00010030567737529016
# 迷路を解くのにかかったステップ数は4です
# 0.00010016878690719249
# 迷路を解くのにかかったステップ数は4です
# 0.00010003218602843257
# 迷路を解くのにかかったステップ数は4です
# 9.989587390169842e-05
# 迷路を解くのにかかったステップ数は4です

# %%
# エージェントの移動の様子を可視化します
# 参考URL http://louistiao.me/posts/notebooks/embedding-matplotlib-animations-in-jupyter-notebooks/
from matplotlib import animation
from IPython.display import HTML


def init():
    # 背景画像の初期化
    line.set_data([], [])
    return (line,)


def animate(i):
    # フレームごとの描画内容
    state = s_a_history[i][0]  # 現在の場所を描く
    x = (state % 4) + 0.5  # 状態のx座標は、3で割った余り+0.5
    y = 3.5 - int(state / 4)  # y座標は3で割った商を2.5から引く
    line.set_data(x, y)
    return (line,)


#　初期化関数とフレームごとの描画関数を用いて動画を作成
anim = animation.FuncAnimation(fig, animate, init_func=init, frames=len(
    s_a_history), interval=200, repeat=False)

HTML(anim.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img227fd2c3cd0043bebecb0575c87f597b">
#   <div class="anim-controls">
#     <input id="_anim_slider227fd2c3cd0043bebecb0575c87f597b" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim227fd2c3cd0043bebecb0575c87f597b.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button title="Decrease speed" onclick="anim227fd2c3cd0043bebecb0575c87f597b.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" onclick="anim227fd2c3cd0043bebecb0575c87f597b.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" onclick="anim227fd2c3cd0043bebecb0575c87f597b.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" onclick="anim227fd2c3cd0043bebecb0575c87f597b.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" onclick="anim227fd2c3cd0043bebecb0575c87f597b.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" onclick="anim227fd2c3cd0043bebecb0575c87f597b.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" onclick="anim227fd2c3cd0043bebecb0575c87f597b.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" onclick="anim227fd2c3cd0043bebecb0575c87f597b.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" onclick="anim227fd2c3cd0043bebecb0575c87f597b.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" action="#n" name="_anim_loop_select227fd2c3cd0043bebecb0575c87f597b"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_227fd2c3cd0043bebecb0575c87f597b"
#              checked>
#       <label for="_anim_radio1_227fd2c3cd0043bebecb0575c87f597b">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_227fd2c3cd0043bebecb0575c87f597b"
#              >
#       <label for="_anim_radio2_227fd2c3cd0043bebecb0575c87f597b">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_227fd2c3cd0043bebecb0575c87f597b"
#              >
#       <label for="_anim_radio3_227fd2c3cd0043bebecb0575c87f597b">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img227fd2c3cd0043bebecb0575c87f597b";
#     var slider_id = "_anim_slider227fd2c3cd0043bebecb0575c87f597b";
#     var loop_select_id = "_anim_loop_select227fd2c3cd0043bebecb0575c87f597b";
#     var frames = new Array(5);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjMuNCwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy8QVMy6AAAACXBIWXMAAAsT\
# AAALEwEAmpwYAAAu20lEQVR4nO3de3wV9Z3/8deHJISEgNGC3AO2WGnYUmsiPy6uoLAaLIqPIv6E\
# n6Liws+i1iJsW1yV2lZ/ilVXV1rNLuIqFtcLWqDVlSrQIuslsXgDL7QiBlBCkFtC0MDn98ecsCGc\
# kABnzpkk7+fjMQ9zZr5nzme+znkz53tm5pi7IyIi0dMm1QWIiEh8CmgRkYhSQIuIRJQCWkQkohTQ\
# IiIRpYAWEYkoBbSISEQpoEVEIkoBLSI
