# %% [markdown]
# ## 2.6 Q学習で迷路を攻略

# %%
# 使用するパッケージの宣言
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 初期位置での迷路の様子

# 図を描く大きさと、図の変数名を宣言
fig = plt.figure(figsize=(5, 5))
ax = plt.gca()

# 赤い壁を描く
plt.plot([1, 1], [0, 1], color='red', linewidth=2)
plt.plot([1, 2], [2, 2], color='red', linewidth=2)
plt.plot([2, 2], [2, 1], color='red', linewidth=2)
plt.plot([2, 3], [1, 1], color='red', linewidth=2)
plt.plot([3, 3], [3, 4], color='red', linewidth=2)
plt.plot([1, 2], [3, 3], color='red', linewidth=2)
plt.plot([3, 3], [1, 2], color='red', linewidth=2)

# 状態を示す文字S0～S12を描く
plt.text(0.5, 3.5, 'S0', size=14, ha='center')
plt.text(1.5, 3.5, 'S1', size=14, ha='center')
plt.text(2.5, 3.5, 'S2', size=14, ha='center')
plt.text(3.5, 3.5, 'S3', size=14, ha='center')
plt.text(0.5, 2.5, 'S4', size=14, ha='center')
plt.text(1.5, 2.5, 'S5', size=14, ha='center')
plt.text(2.5, 2.5, 'S6', size=14, ha='center')
plt.text(3.5, 2.5, 'S7', size=14, ha='center')
plt.text(0.5, 1.5, 'S8', size=14, ha='center')
plt.text(1.5, 1.5, 'S9', size=14, ha='center')
plt.text(2.5, 1.5, 'S10', size=14, ha='center')
plt.text(3.5, 1.5, 'S11', size=14, ha='center')
plt.text(0.5, 0.5, 'S12', size=14, ha='center')
plt.text(1.5, 0.5, 'S13', size=14, ha='center')
plt.text(2.5, 0.5, 'S14', size=14, ha='center')
plt.text(3.5, 0.5, 'S15', size=14, ha='center')
plt.text(0.5, 3.3, 'START', ha='center')
plt.text(3.5, 0.3, 'GOAL', ha='center')

# 描画範囲の設定と目盛りを消す設定
ax.set_xlim(0, 4)
ax.set_ylim(0, 4)
plt.tick_params(axis='both', which='both', bottom='off', top='off',
                labelbottom='off', right='off', left='off', labelleft='off')

# 現在地S0に緑丸を描画する
line, = ax.plot([0.5], [3.5], marker="o", color='b', markersize=60)

# %%
# 初期の方策を決定するパラメータtheta_0を設定

# 行は状態0～7、列は移動方向で↑、→、↓、←、右上、左上、右下、左下を表す
theta_0 = np.array([[np.nan, 1, 1, np.nan, np.nan, np.nan, 1, np.nan],  # s0
                    [np.nan, 1, np.nan, 1, np.nan, np.nan, 1, 1],  # s1
                    [np.nan, np.nan, 1, 1, np.nan ,np.nan, 1, 1],  # s2
                    [np.nan, np.nan, 1, np.nan, np.nan, np.nan, np.nan, 1],  # s3
                    [1, 1, 1, np.nan, 1, np.nan, 1, np.nan],  # s4
                    [np.nan, 1, np.nan, 1, 1, 1, 1, 1],  # s5
                    [1, 1, 1, 1, 1, 1, np.nan, np.nan],  # s6
                    [1, np.nan, 1, 1, np.nan, 1, np.nan, 1],# s7
                    [1, 1, 1, np.nan, 1, np.nan, 1, np.nan],  # s8
                    [np.nan, np.nan, 1, 1, np.nan, 1, 1, 1],  # s9
                    [1, np.nan, np.nan, np.nan, 1, 1, np.nan, np.nan],  # s10
                    [1, np.nan, 1, np.nan, np.nan, 1, np.nan, 1],  # s11
                    [1, np.nan, np.nan, np.nan, 1, np.nan, np.nan, np.nan],  # s12
                    [1, 1, np.nan, np.nan, np.nan, 1, np.nan, np.nan],  # s13
                    [np.nan, 1, np.nan, 1, 1, 1, np.nan, np.nan],  # s14
                    # ※s15はゴールなので、方策はなし
                    ])

# %%
# 方策パラメータtheta_0をランダム方策piに変換する関数の定義


def simple_convert_into_pi_from_theta(theta):
    '''単純に割合を計算する'''

    [m, n] = theta.shape  # thetaの行列サイズを取得
    pi = np.zeros((m, n))
    for i in range(0, m):
        pi[i, :] = theta[i, :] / np.nansum(theta[i, :])  # 割合の計算

    pi = np.nan_to_num(pi)  # nanを0に変換

    return pi

# ランダム行動方策pi_0を求める
pi_0 = simple_convert_into_pi_from_theta(theta_0)

# %%
# 初期の行動価値関数Qを設定

[a, b] = theta_0.shape  # 行と列の数をa, bに格納
Q = np.random.rand(a, b) * theta_0
# * theta0をすることで要素ごとに掛け算をし、Qの壁方向の値がnanになる

# %%
# 1step移動後の状態sを求める関数を定義


def get_action(s, Q, epsilon, pi_0):
    direction = ["up", "right", "down", "left","upper right","upper left","lower right","lower left"]

    # 行動を決める
    if np.random.rand() < epsilon:
        # εの確率でランダムに動く
        next_direction = np.random.choice(direction, p=pi_0[s, :])
    else:
        # Qの最大値の行動を採用する
        next_direction = direction[np.nanargmax(Q[s, :])]
    
    # 行動をindexに
    if next_direction == "up":
        action = 0
    elif next_direction == "right":
        action = 1
    elif next_direction == "down":
        action = 2
    elif next_direction == "left":
        action = 3
    elif next_direction == "upper right":
        action = 4
    elif next_direction == "upper left":
        action = 5
    elif next_direction == "lower right":
        action = 6
    elif next_direction == "lower left":
        action = 7
    return action

def get_s_next(s, a, Q, epsilon, pi_0):
    direction = ["up", "right", "down", "left","upper right","upper left","lower right","lower left"]
    next_direction = direction[a]  # 行動aの方向
   
    # 行動から次の状態を決める
    if next_direction == "up":
        s_next = s - 4  # 上に移動するときは状態の数字が3小さくなる
    elif next_direction == "right":
        s_next = s + 1  # 右に移動するときは状態の数字が1大きくなる
    elif next_direction == "down":
        s_next = s + 4  # 下に移動するときは状態の数字が3大きくなる
    elif next_direction == "left":
        s_next = s - 1  # 左に移動するときは状態の数字が1小さくなる
    elif next_direction == "upper right":
        s_next = s - 3  # 右上に移動するときは状態の数字が2小さくなる
    elif next_direction == "upper left":
        s_next = s - 5  # 左上に移動するときは状態の数字が4小さくなる
    elif next_direction == "lower right":
        s_next = s + 5  # 右下に移動するときは状態の数字が4大きくなる
    elif next_direction == "lower left":
        s_next = s + 3  # 左下に移動するときは状態の数字が2大きくなる
    return s_next

# %%
# Q学習による行動価値関数Qの更新


def Q_learning(s, a, r, s_next, Q, eta, gamma):

    if s_next == 15:  # ゴールした場合
        Q[s, a] = Q[s, a] + eta * (r - Q[s, a])

    else:
        Q[s, a] = Q[s, a] + eta * (r + gamma * np.nanmax(Q[s_next,: ]) - Q[s, a])

    return Q

# %%
# Q学習で迷路を解く関数の定義、状態と行動の履歴および更新したQを出力


def goal_maze_ret_s_a_Q(Q, epsilon, eta, gamma, pi):
    s = 0  # スタート地点
    a = a_next = get_action(s, Q, epsilon, pi)  # 初期の行動
    s_a_history = [[0, np.nan]]  # エージェントの移動を記録するリスト

    while (1):  # ゴールするまでループ
        a = a_next  # 行動更新

        s_a_history[-1][1] = a
        # 現在の状態（つまり一番最後なのでindex=-1）に行動を代入

        s_next = get_s_next(s, a, Q, epsilon, pi)
        # 次の状態を格納

        s_a_history.append([s_next, np.nan])
        # 次の状態を代入。行動はまだ分からないのでnanにしておく

        # 報酬を与え,　次の行動を求めます
        if s_next == 15:
            r = 1  # ゴールにたどり着いたなら報酬を与える
            a_next = np.nan
        else:
            r = 0
            a_next = get_action(s_next, Q, epsilon, pi)
            # 次の行動a_nextを求めます。

        # 価値関数を更新
        Q = Q_learning(s, a, r, s_next, Q, eta, gamma)

        # 終了判定
        if s_next == 15:  # ゴール地点なら終了
            break
        else:
            s = s_next

    return [s_a_history, Q]

# %%
# Q学習で迷路を解く

eta = 0.1  # 学習率
gamma = 0.9  # 時間割引率
epsilon = 0.5  # ε-greedy法の初期値
v = np.nanmax(Q, axis=1)  # 状態ごとに価値の最大値を求める
is_continue = True
episode = 1

V = []  # エピソードごとの状態価値を格納する
V.append(np.nanmax(Q, axis=1))  # 状態ごとに行動価値の最大値を求める

while is_continue:  # is_continueがFalseになるまで繰り返す
    print("エピソード:" + str(episode))

    # ε-greedyの値を少しずつ小さくする
    epsilon = epsilon / 2

    # Q学習で迷路を解き、移動した履歴と更新したQを求める
    [s_a_history, Q] = goal_maze_ret_s_a_Q(Q, epsilon, eta, gamma, pi_0)

    # 状態価値の変化
    new_v = np.nanmax(Q, axis=1)  # 状態ごとに行動価値の最大値を求める
    print(np.sum(np.abs(new_v - v)))  # 状態価値関数の変化を出力
    v = new_v
    V.append(v)  # このエピソード終了時の状態価値関数を追加

    print("迷路を解くのにかかったステップ数は" + str(len(s_a_history) - 1) + "です")

    # 100エピソード繰り返す
    episode = episode + 1
    if episode > 100:
        break
# Out:
# エピソード:1
# 0.9843710841759286
# 迷路を解くのにかかったステップ数は162です
# エピソード:2
# 2.3688738910580716
# 迷路を解くのにかかったステップ数は651です
# エピソード:3
# 1.0857310244615817
# 迷路を解くのにかかったステップ数は417です
# エピソード:4
# 1.4926340329528784
# 迷路を解くのにかかったステップ数は902です
# エピソード:5
# 0.7014894311622754
# 迷路を解くのにかかったステップ数は481です
# エピソード:6
# 0.09220576520590879
# 迷路を解くのにかかったステップ数は11です
# エピソード:7
# 0.07649533916583401
# 迷路を解くのにかかったステップ数は9です
# エピソード:8
# 0.06196417278192978
# 迷路を解くのにかかったステップ数は7です
# エピソード:9
# 0.05325535394093878
# 迷路を解くのにかかったステップ数は7です
# エピソード:10
# 0.046623961290171934
# 迷路を解くのにかかったステップ数は5です
# エピソード:11
# 0.04503060696058753
# 迷路を解くのにかかったステップ数は5です
# エピソード:12
# 0.043154122325116284
# 迷路を解くのにかかったステップ数は5です
# エピソード:13
# 0.04109489302410135
# 迷路を解くのにかかったステップ数は5です
# エピソード:14
# 0.039219125971836966
# 迷路を解くのにかかったステップ数は5です
# エピソード:15
# 0.03879310422102128
# 迷路を解くのにかかったステップ数は5です
# エピソード:16
# 0.0383735649366026
# 迷路を解くのにかかったステップ数は5です
# エピソード:17
# 0.03795302339683915
# 迷路を解くのにかかったステップ数は5です
# エピソード:18
# 0.0375248145959845
# 迷路を解くのにかかったステップ数は5です
# エピソード:19
# 0.0370831878534158
# 迷路を解くのにかかったステップ数は5です
# エピソード:20
# 0.03662334801279987
# 迷路を解くのにかかったステップ数は5です
# エピソード:21
# 0.036141455955742696
# 迷路を解くのにかかったステップ数は5です
# エピソード:22
# 0.035634598852036015
# 迷路を解くのにかかったステップ数は5です
# エピソード:23
# 0.03510073862360996
# 迷路を解くのにかかったステップ数は5です
# エピソード:24
# 0.03453864546169094
# 迷路を解くのにかかったステップ数は5です
# エピソード:25
# 0.0339478218629754
# 迷路を解くのにかかったステップ数は5です
# エピソード:26
# 0.03332842150301146
# 迷路を解くのにかかったステップ数は5です
# エピソード:27
# 0.03268116631056445
# 迷路を解くのにかかったステップ数は5です
# エピソード:28
# 0.03200726431701545
# 迷路を解くのにかかったステップ数は5です
# エピソード:29
# 0.03130833020513496
# 迷路を解くのにかかったステップ数は5です
# エピソード:30
# 0.030586309950535406
# 迷路を解くのにかかったステップ数は5です
# エピソード:31
# 0.029843410518366198
# 迷路を解くのにかかったステップ数は5です
# エピソード:32
# 0.029082035231500658
# 迷路を解くのにかかったステップ数は5です
# エピソード:33
# 0.028304725150998522
# 迷路を解くのにかかったステップ数は5です
# エピソード:34
# 0.027514106593327203
# 迷路を解くのにかかったステップ数は5です
# エピソード:35
# 0.026712844741715147
# 迷路を解くのにかかったステップ数は5です
# エピソード:36
# 0.025903603182599044
# 迷路を解くのにかかったステップ数は5です
# エピソード:37
# 0.025089009105156823
# 迷路を解くのにかかったステップ数は5です
# エピソード:38
# 0.02427162383625947
# 迷路を解くのにかかったステップ数は5です
# エピソード:39
# 0.023453918339642554
# 迷路を解くのにかかったステップ数は5です
# エピソード:40
# 0.022638253282301457
# 迷路を解くのにかかったステップ数は5です
# エピソード:41
# 0.021826863259409912
# 迷路を解くのにかかったステップ数は5です
# エピソード:42
# 0.021021844768351228
# 迷路を解くのにかかったステップ数は5です
# エピソード:43
# 0.020225147530214038
# 迷路を解くのにかかったステップ数は5です
# エピソード:44
# 0.019438568771201536
# 迷路を解くのにかかったステップ数は5です
# エピソード:45
# 0.018663750095126053
# 迷路を解くのにかかったステップ数は5です
# エピソード:46
# 0.01790217660006721
# 迷路を解くのにかかったステップ数は5です
# エピソード:47
# 0.01715517791623844
# 迷路を解くのにかかったステップ数は5です
# エピソード:48
# 0.01642393086718552
# 迷路を解くのにかかったステップ数は5です
# エピソード:49
# 0.015709463481940023
# 迷路を解くのにかかったステップ数は5です
# エピソード:50
# 0.015012660111055731
# 迷路を解くのにかかったステップ数は5です
# エピソード:51
# 0.01433426742417343
# 迷路を解くのにかかったステップ数は5です
# エピソード:52
# 0.013674901090527936
# 迷路を解くのにかかったステップ数は5です
# エピソード:53
# 0.013035052966428262
# 迷路を解くのにかかったステップ数は5です
# エピソード:54
# 0.012415098635007449
# 迷路を解くのにかかったステップ数は5です
# エピソード:55
# 0.011815305163389689
# 迷路を解くのにかかったステップ数は5です
# エピソード:56
# 0.011235838960778288
# 迷路を解くのにかかったステップ数は5です
# エピソード:57
# 0.010676773637828041
# 迷路を解くのにかかったステップ数は5です
# エピソード:58
# 0.010138097783038091
# 迷路を解くのにかかったステップ数は5です
# エピソード:59
# 0.009619722585822
# 迷路を解くのにかかったステップ数は5です
# エピソード:60
# 0.00912148924845535
# 迷路を解くのにかかったステップ数は5です
# エピソード:61
# 0.008643176140292419
# 迷路を解くのにかかったステップ数は5です
# エピソード:62
# 0.008184505657615526
# 迷路を解くのにかかったステップ数は5です
# エピソード:63
# 0.007745150761256703
# 迷路を解くのにかかったステップ数は5です
# エピソード:64
# 0.0073247411718467825
# 迷路を解くのにかかったステップ数は5です
# エピソード:65
# 0.006922869209238236
# 迷路を解くのにかかったステップ数は5です
# エピソード:66
# 0.006539095268449313
# 迷路を解くのにかかったステップ数は5です
# エピソード:67
# 0.006172952929416442
# 迷路を解くのにかかったステップ数は5です
# エピソード:68
# 0.005823953702053797
# 迷路を解くのにかかったステップ数は5です
# エピソード:69
# 0.005491591411621921
# 迷路を解くのにかかったステップ数は5です
# エピソード:70
# 0.005175346232322631
# 迷路を解くのにかかったステップ数は5です
# エピソード:71
# 0.004874688379404635
# 迷路を解くのにかかったステップ数は5です
# エピソード:72
# 0.00458908147193271
# 迷路を解くのにかかったステップ数は5です
# エピソード:73
# 0.004317985579853523
# 迷路を解くのにかかったステップ数は5です
# エピソード:74
# 0.004060859970058561
# 迷路を解くのにかかったステップ数は5です
# エピソード:75
# 0.0038171655669275717
# 迷路を解くのにかかったステップ数は5です
# エピソード:76
# 0.0035863671433107314
# 迷路を解くのにかかったステップ数は5です
# エピソード:77
# 0.0033679352581647004
# 迷路を解くのにかかったステップ数は5です
# エピソード:78
# 0.0031613479570961056
# 迷路を解くのにかかったステップ数は5です
# エピソード:79
# 0.0029660922519475497
# 迷路を解くのにかかったステップ数は5です
# エピソード:80
# 0.002781665395291233
# 迷路を解くのにかかったステップ数は5です
# エピソード:81
# 0.002607575965309583
# 迷路を解くのにかかったステップ数は5です
# エピソード:82
# 0.0024433447760714433
# 迷路を解くのにかかったステップ数は5です
# エピソード:83
# 0.002288505627659587
# 迷路を解くのにかかったステップ数は5です
# エピソード:84
# 0.0021426059099949324
# 迷路を解くのにかかったステップ数は5です
# エピソード:85
# 0.002005207073563775
# 迷路を解くのにかかったステップ数は5です
# エピソード:86
# 0.0018758849795688093
# 迷路を解くのにかかったステップ数は5です
# エピソード:87
# 0.001754230141341906
# 迷路を解くのにかかったステップ数は5です
# エピソード:88
# 0.0016398478681491913
# 迷路を解くのにかかったステップ数は5です
# エピソード:89
# 0.0015323583218256331
# 迷路を解くのにかかったステップ数は5です
# エピソード:90
# 0.001431396495982118
# 迷路を解くのにかかったステップ数は5です
# エピソード:91
# 0.0013366121268537645
# 迷路を解くのにかかったステップ数は5です
# エピソード:92
# 0.0012476695441929753
# 迷路を解くのにかかったステップ数は5です
# エピソード:93
# 0.0011642474699761207
# 迷路を解くのにかかったステップ数は5です
# エピソード:94
# 0.0010860387720800224
# 迷路を解くのにかかったステップ数は5です
# エピソード:95
# 0.0010127501794884308
# 迷路を解くのにかかったステップ数は5です
# エピソード:96
# 0.0009441019650365812
# 迷路を解くのにかかったステップ数は5です
# エピソード:97
# 0.0008798276011654504
# 迷路を解くのにかかったステップ数は5です
# エピソード:98
# 0.0008196733936568501
# 迷路を解くのにかかったステップ数は5です
# エピソード:99
# 0.0007633980978455357
# 迷路を解くのにかかったステップ数は5です
# エピソード:100
# 0.0007107725213654215
# 迷路を解くのにかかったステップ数は5です

# %%
# エージェントの移動の様子を可視化します
# 参考URL http://louistiao.me/posts/notebooks/embedding-matplotlib-animations-in-jupyter-notebooks/
from matplotlib import animation
from IPython.display import HTML


def init():
    # 背景画像の初期化
    line.set_data([], [])
    return (line,)


def animate(i):
    # フレームごとの描画内容
    state = s_a_history[i][0]  # 現在の場所を描く
    x = (state % 4) + 0.5  # 状態のx座標は、3で割った余り+0.5
    y = 3.5 - int(state / 4)  # y座標は3で割った商を2.5から引く
    line.set_data(x, y)
    return (line,)


#　初期化関数とフレームごとの描画関数を用いて動画を作成
anim = animation.FuncAnimation(fig, animate, init_func=init, frames=len(
    s_a_history), interval=200, repeat=False)

HTML(anim.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img74a9affebf654ff4be0e869eeec31a39">
#   <div class="anim-controls">
#     <input id="_anim_slider74a9affebf654ff4be0e869eeec31a39" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim74a9affebf654ff4be0e869eeec31a39.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button title="Decrease speed" onclick="anim74a9affebf654ff4be0e869eeec31a39.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" onclick="anim74a9affebf654ff4be0e869eeec31a39.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" onclick="anim74a9affebf654ff4be0e869eeec31a39.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" onclick="anim74a9affebf654ff4be0e869eeec31a39.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" onclick="anim74a9affebf654ff4be0e869eeec31a39.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" onclick="anim74a9affebf654ff4be0e869eeec31a39.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" onclick="anim74a9affebf654ff4be0e869eeec31a39.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" onclick="anim74a9affebf654ff4be0e869eeec31a39.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" onclick="anim74a9affebf654ff4be0e869eeec31a39.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" action="#n" name="_anim_loop_select74a9affebf654ff4be0e869eeec31a39"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_74a9affebf654ff4be0e869eeec31a39"
#              checked>
#       <label for="_anim_radio1_74a9affebf654ff4be0e869eeec31a39">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_74a9affebf654ff4be0e869eeec31a39"
#              >
#       <label for="_anim_radio2_74a9affebf654ff4be0e869eeec31a39">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_74a9affebf654ff4be0e869eeec31a39"
#              >
#       <label for="_anim_radio3_74a9affebf654ff4be0e869eeec31a39">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img74a9affebf654ff4be0e869eeec31a39";
#     var slider_id = "_anim_slider74a9affebf654ff4be0e869eeec31a39";
#     var loop_select_id = "_anim_loop_select74a9affebf654ff4be0e869eeec31a39";
#     var frames = new Array(6);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjMuNCwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy8QVMy6AAAACXBIWXMAAAsT\
# AAALEwEAmpwYAAAu20lEQVR4nO3de3wV9Z3/8deHJISEgNGC3AO2WGnYUmsiPy6uoLAaLIqPIv6E\
# n6Liws+i1iJsW1yV2lZ/ilVXV1rNLuIqFtcLWqDVlSrQIuslsXgDL7QiBlBCkFtC0MDn98ecsCGc\
# kABnzpkk7+fjMQ9zZr5nzme+znkz53tm5pi7IyIi0dMm1QWIiEh8CmgRkYhSQIuIRJQCWkQkohTQ\
# IiIRpYAWEYkoBbSISEQpoEVEIkoBLSI

# %%
# 状態価値の変化を可視化します
# 参考URL http://louistiao.me/posts/notebooks/embedding-matplotlib-animations-in-jupyter-notebooks/
from matplotlib import animation
from IPython.display import HTML
import matplotlib.cm as cm  # color map


def init():
    # 背景画像の初期化
    line.set_data([], [])
    return (line,)


def animate(i):
    # フレームごとの描画内容
    # 各マスに状態価値の大きさに基づく色付きの四角を描画
    line, = ax.plot([0.5], [3.5], marker="s",
                    color=cm.jet(V[i][0]), markersize=85)  # S0
    line, = ax.plot([1.5], [3.5], marker="s",
                    color=cm.jet(V[i][1]), markersize=85)  # S1
    line, = ax.plot([2.5], [3.5], marker="s",
                    color=cm.jet(V[i][2]), markersize=85)  # S2
    line, = ax.plot([3.5], [3.5], marker="s",
                    color=cm.jet(V[i][3]), markersize=85)  # S3
    line, = ax.plot([0.5], [2.5], marker="s",
                    color=cm.jet(V[i][4]), markersize=85)  # S4
    line, = ax.plot([1.5], [2.5], marker="s",
                    color=cm.jet(V[i][5]), markersize=85)  # S5
    line, = ax.plot([2.5], [2.5], marker="s",
                    color=cm.jet(V[i][6]), markersize=85)  # S6
    line, = ax.plot([3.5], [2.5], marker="s",
                    color=cm.jet(V[i][7]), markersize=85)  # S7
    line, = ax.plot([0.5], [1.5], marker="s",
                    color=cm.jet(V[i][8]), markersize=85)  # S8
    line, = ax.plot([1.5], [1.5], marker="s",
                    color=cm.jet(V[i][9]), markersize=85)  # S9
    line, = ax.plot([2.5], [1.5], marker="s",
                    color=cm.jet(V[i][10]), markersize=85)  # S10
    line, = ax.plot([3.5], [1.5], marker="s",
                    color=cm.jet(V[i][11]), markersize=85)  # S11
    line, = ax.plot([0.5], [0.5], marker="s",
                    color=cm.jet(V[i][12]), markersize=85)  # S12
    line, = ax.plot([1.5], [0.5], marker="s",
                    color=cm.jet(V[i][13]), markersize=85)  # S13
    line, = ax.plot([2.5], [0.5], marker="s",
                    color=cm.jet(V[i][14]), markersize=85)  # S14
    line, = ax.plot([3.5], [0.5], marker="s",
                    color=cm.jet(1.0), markersize=85)  # S15
    return (line,)


#　初期化関数とフレームごとの描画関数を用いて動画を作成
anim = animation.FuncAnimation(
    fig, animate, init_func=init, frames=len(V), interval=200, repeat=False)

HTML(anim.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imge03ada7d1d6c465f9a173907ab12cc65">
#   <div class="anim-controls">
#     <input id="_anim_slidere03ada7d1d6c465f9a173907ab12cc65" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anime03ada7d1d6c465f9a173907ab12cc65.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button title="Decrease speed" onclick="anime03ada7d1d6c465f9a173907ab12cc65.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" onclick="anime03ada7d1d6c465f9a173907ab12cc65.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" onclick="anime03ada7d1d6c465f9a173907ab12cc65.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" onclick="anime03ada7d1d6c465f9a173907ab12cc65.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" onclick="anime03ada7d1d6c465f9a173907ab12cc65.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" onclick="anime03ada7d1d6c465f9a173907ab12cc65.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" onclick="anime03ada7d1d6c465f9a173907ab12cc65.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" onclick="anime03ada7d1d6c465f9a173907ab12cc65.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" onclick="anime03ada7d1d6c465f9a173907ab12cc65.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" action="#n" name="_anim_loop_selecte03ada7d1d6c465f9a173907ab12cc65"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_e03ada7d1d6c465f9a173907ab12cc65"
#              checked>
#       <label for="_anim_radio1_e03ada7d1d6c465f9a173907ab12cc65">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_e03ada7d1d6c465f9a173907ab12cc65"
#              >
#       <label for="_anim_radio2_e03ada7d1d6c465f9a173907ab12cc65">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_e03ada7d1d6c465f9a173907ab12cc65"
#              >
#       <label for="_anim_radio3_e03ada7d1d6c465f9a173907ab12cc65">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imge03ada7d1d6c465f9a173907ab12cc65";
#     var slider_id = "_anim_slidere03ada7d1d6c465f9a173907ab12cc65";
#     var loop_select_id = "_anim_loop_selecte03ada7d1d6c465f9a173907ab12cc65";
#     var frames = new Array(101);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjMuNCwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy8QVMy6AAAACXBIWXMAAAsT\
# AAALEwEAmpwYAAAuKklEQVR4nO3deXxU9b3/8dcnGwECBtmCrCq4ACKbisVWFBfA9YrUpeJ1KdSl\
# vV20/alVpNerbb3VSqsVc6UutdVq9VZU9BZ3KIKCorK44AYICgTDFgIk+f7++J6UYZhIgJyZ7yTv\
# 5+Mxj0zO+c7hk8PMe77zPd9zxpxziIhIeHIyXYCIiKSmgBYRCZQCWkQkUApoEZFAKaBFRAKlgBYR\
# CZQCWkQkUApoEZFAKaBFRAKlgBYRC
